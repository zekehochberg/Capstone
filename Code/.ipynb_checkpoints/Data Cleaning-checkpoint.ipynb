# %%
import pandas as pd
import os

# %% [markdown]
# ### Read in Data

# %%
for (dirpath, dirnames, filenames) in os.walk('../Data/recipes/'):
    break

# %%
len(filenames)
# Out:
# 24

# %%
df = pd.DataFrame()
for i in filenames:
    new_df = pd.read_csv('../Data/recipes/' + i)
    df = pd.concat([df, new_df], axis=0, ignore_index=True)

# %%
# Save complete dataframe as new file
df.to_csv('../Data/recipes/complete_brewtoad_recipes.csv')

# %% [markdown]
# ### Data Cleaning

# %%
df.head()
# Out:
#    Unnamed: 0    ABV     FG  IBU     OG  SRM  boil_time boil_time_units  \
# 0           0  0.050  1.010   77  1.048   13         60             min
# 1           1  0.055  1.013  132  1.055   38         60             min
# 2           2  0.062  1.016   23  1.063    7         80             min
# 3           3  0.049  1.015   26  1.052    4         60             min
# 4           4  0.048  1.009   29  1.046    6         60             min
#
#    extras                                       fermentables  \
# 0       1  {0: {'amount': 6.0, 'amount_unit': 'lb', 'name...
# 1       0  {0: {'amount': 9.0, 'amount_unit': 'lb', 'name...
# 2       0  {0: {'amount': 5.5, 'amount_unit': 'lb', 'name...
# 3       0  {0: {'amount': 6.0, 'amount_unit': 'lb', 'name...
# 4       0  {0: {'amount': 2.0, 'amount_unit': 'lb', 'name...
#
#                                                 hops  \
# 0  {0: {'amount': 1.5, 'amount_unit': 'oz', 'name...
# 1  {0: {'amount': 2.0, 'amount_unit': 'oz', 'name...
# 2  {0: {'amount': 1.6, 'amount_unit': 'oz', 'name...
# 3  {0: {'amount': 1.0, 'amount_unit': 'oz', 'name...
# 4  {0: {'amount': 0.75, 'amount_unit': 'oz', 'nam...
#
#                          name                         style  volume  \
# 0   Bag of Tricks Belgian IPA                  American IPA    6.00
# 1  Sessionable Cascadian Dark                  American IPA    5.00
# 2               Pangtoberfest            Oktoberfest/Märzen    6.00
# 3                 Oberon 2013    American Wheat or Rye Beer    6.50
# 4                         Rye  Roggenbier (German Rye Beer)    2.75
#
#   volume_units  yeast_attenuation          yeast_lab  \
# 0          gal              0.800  White Labs WLP565
# 1          gal              0.765              US-05
# 2          gal              0.750  White Labs WLP029
# 3          gal              0.720  White Labs WLP320
# 4          gal              0.800                NaN
#
#                           yeast_name
# 0             Belgian Saison I Yeast
# 1                    Safale American
# 2            German Ale/Kölsch Yeast
# 3      American Hefeweizen Ale Yeast
# 4  American Farmhouse Blend (WLP670)

# %%
# Drop redundant index column
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Check to make sure that it dropped
df.head()
# Out:
#      ABV     FG  IBU     OG  SRM  boil_time boil_time_units  extras  \
# 0  0.050  1.010   77  1.048   13         60             min       1
# 1  0.055  1.013  132  1.055   38         60             min       0
# 2  0.062  1.016   23  1.063    7         80             min       0
# 3  0.049  1.015   26  1.052    4         60             min       0
# 4  0.048  1.009   29  1.046    6         60             min       0
#
#                                         fermentables  \
# 0  {0: {'amount': 6.0, 'amount_unit': 'lb', 'name...
# 1  {0: {'amount': 9.0, 'amount_unit': 'lb', 'name...
# 2  {0: {'amount': 5.5, 'amount_unit': 'lb', 'name...
# 3  {0: {'amount': 6.0, 'amount_unit': 'lb', 'name...
# 4  {0: {'amount': 2.0, 'amount_unit': 'lb', 'name...
#
#                                                 hops  \
# 0  {0: {'amount': 1.5, 'amount_unit': 'oz', 'name...
# 1  {0: {'amount': 2.0, 'amount_unit': 'oz', 'name...
# 2  {0: {'amount': 1.6, 'amount_unit': 'oz', 'name...
# 3  {0: {'amount': 1.0, 'amount_unit': 'oz', 'name...
# 4  {0: {'amount': 0.75, 'amount_unit': 'oz', 'nam...
#
#                          name                         style  volume  \
# 0   Bag of Tricks Belgian IPA                  American IPA    6.00
# 1  Sessionable Cascadian Dark                  American IPA    5.00
# 2               Pangtoberfest            Oktoberfest/Märzen    6.00
# 3                 Oberon 2013    American Wheat or Rye Beer    6.50
# 4                         Rye  Roggenbier (German Rye Beer)    2.75
#
#   volume_units  yeast_attenuation          yeast_lab  \
# 0          gal              0.800  White Labs WLP565
# 1          gal              0.765              US-05
# 2          gal              0.750  White Labs WLP029
# 3          gal              0.720  White Labs WLP320
# 4          gal              0.800                NaN
#
#                           yeast_name
# 0             Belgian Saison I Yeast
# 1                    Safale American
# 2            German Ale/Kölsch Yeast
# 3      American Hefeweizen Ale Yeast
# 4  American Farmhouse Blend (WLP670)

# %%
# Find number of recipes collected
df.shape
# Out:
# (71954, 17)

# %%
# Check which units were used for the boiling time
df['boil_time_units'].value_counts()
# Out:
# min    71954
# Name: boil_time_units, dtype: int64

# %% [markdown]
# All beers used minutes for the unit of time in the boil, so I can drop this column as it does not contain any useful information

# %%
# Drop boiling time units column
df.drop('boil_time_units', axis=1, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Volume Conversion

# %%
df['volume_units'].value_counts()
# Out:
# gal    64517
# L       7437
# Name: volume_units, dtype: int64

# %%
# Write function to change L to gallons
def liter_to_gal(row):
    # Look for where the units are liters
    if row['volume_units'] == 'L':
        # 1 Liter = 0.2641720524 gallons, multiply by this conversion factor
        return round(row['volume'] * 0.2641720524, 2)
    return round(row['volume'], 2)

# %%
# Convert all volume measurements
df['volume'] = df.apply(liter_to_gal, axis=1)

# %% [markdown]
# Now that all volume units have been converted, I can drop the volume units column as it no longer contains helpful information

# %%
df.drop('volume_units', axis=1, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Find all fermentables and hops

# %% [markdown]
# When I saved the dataframes my web scraper created as a .csv file, it changed the dictionary values for the hops and the grains to be strings. I will convert these strings back to dictionaries below

# %%
import ast

dict_cols = ['fermentables', 'hops']
for col in dict_cols:
    df[col] = df[col].map(ast.literal_eval)

# %%
grain_list = []
for i in df.loc[:, 'fermentables'].values:
    for j in i.values():
        temp = j.copy()
        del temp['amount']
        del temp['amount_unit']
        del temp['use']
        if temp not in grain_list:
            grain_list.append(temp)
grain_df = pd.DataFrame(grain_list)
grain_df
# Out:
#       PPG  color color_unit               maltster  \
# 0      37      1         °L                 Briess
# 1      43      3         °L                Muntons
# 2      35      3         °L                 Briess
# 3      36     75         °L                    Any
# 4      34     40         °L                 Briess
# 5      36      2         °L                    Any
# 6      34     40         °L                    Any
# 7      25    500         °L                    Any
# 8      35      3         °L                    Any
# 9      37      1         °L             GlobalMalt
# 10     37      5         °L             Weyermann®
# 11     34     22         °L                    Any
# 12     35     34         °L             Weyermann®
# 13     41      2         °L                   Rahr
# 14     34      6         °L                    Any
# 15     34     10         °L                 Briess
# 16     34      3         °L                    Any
# 17     35      9         °L                    Any
# 18     36      1         °L                 Briess
# 19     32      2         °L                    Any
# 20     34      2         °L                    Any
# 21     34     15         °L                    Any
# 22     34     34         °L                    Any
# 23     34      1         °L                 Briess
# 24     34     20         °L                 Briess
# 25     34     27         °L                    Any
# 26     31      1         °L              Simpson's
# 27     37     23         °L              Gambrinus
# 28     33      4         °L                    Any
# 29     35      2         °L                    Any
# ...   ...    ...        ...                    ...
# 5318   22    430         °L                    Any
# 5319   37      1         °L              Gambrinus
# 5320   34     10         °L              Gambrinus
# 5321   34     35         °L             Weyermann®
# 5322   34    115         °L                 Castle
# 5323   35      4         °L             Weyermann®
# 5324   32    450         °L             Weyermann®
# 5325   38      0         °L                    Any
# 5326   46      2         °L                    Any
# 5327   36      1         °L                    Any
# 5328   33     10         °L                    Any
# 5329   34    500         °L                    Any
# 5330   33     77         °L                    Any
# 5331   34    180         °L                    Any
# 5332   37      2         °L                    Any
# 5333   37      3         °L                    Any
# 5334    3      2         °L                 Briess
# 5335   37      1         °L                    Any
# 5336   36      2         °L                 Bairds
# 5337   37      2         °L                 Bairds
# 5338   33    160         °L                 Bairds
# 5339    2      1         °L                    Any
# 5340   34     12         °L                    Any
# 5341   34     15         °L                    Any
# 5342   33      2         °L          Great Western
# 5343   37      7         °L  Thomas Fawcett & Sons
# 5344   36     56         °L                 Castle
# 5345    0      0         °L          Great Western
# 5346   38      1         °L                   Rahr
# 5347   37      4         °L                 Briess
#
#                                  name
# 0                  2-Row Brewers Malt
# 1               Plain Extra Light DME
# 2                         Vienna Malt
# 3                  Candi Sugar, Amber
# 4              2-Row Caramel Malt 40L
# 5                Pale Malt (2 Row) US
# 6          Caramel/Crystal Malt - 40L
# 7                 Black (Patent) Malt
# 8                       German Vienna
# 9                         Pilsen Malt
# 10                      Munich Malt I
# 11                 Belgian CaraVienne
# 12                      CARAMUNICH® I
# 13                        White Wheat
# 14                    's Light Munich
# 15                   Caramel Malt 10L
# 16                                Rye
# 17                     Munich Type II
# 18                 6-Row Brewers Malt
# 19          Breiss 6-row Brewers Malt
# 20             British Golden Promise
# 21                        Caramalt ()
# 22            English Crystal 30-37 L
# 23                     Carapils® Malt
# 24                   Caramel Malt 20L
# 25                    Melanoidin Malt
# 26                         Oat Flakes
# 27                         Honey Malt
# 28                    American Vienna
# 29                  Best Malz Pilsner
# ...                               ...
# 5318     Carafa Special II (Dehusked)
# 5319           Gambrinus Pilsner Malt
# 5320            Gambrinus Munich Malt
# 5321       Weyermann CaraMunich® Malt
# 5322            Castle Special B Malt
# 5323            Weyermann Vienna Malt
# 5324              Weyermann Carafa II
# 5325                      Wheat flour
# 5326                       Piloncillo
# 5327  Local floor malted pilsner malt
# 5328   American Munich (Light, 8-12L)
# 5329                   Chocolate (UK)
# 5330                 Crystal 77L (UK)
# 5331                   Special B (BE)
# 5332                       Optic (UK)
# 5333                   Pale Malt (US)
# 5334                   CBW Munich LME
# 5335           2-Row (Ontario Select)
# 5336        Maris Otter Pale Ale Malt
# 5337                       Wheat (UK)
# 5338     Extra Dark Crystal 160L (UK)
# 5339             Lactose (Milk Sugar)
# 5340                            Red X
# 5341               Caramel Wheat (DE)
# 5342                      Rolled Oats
# 5343                        Mild (UK)
# 5344                   Crystal 150EBC
# 5345                       Rice Hulls
# 5346                      NZ Pale Ale
# 5347                       2-Row (US)
#
# [5348 rows x 5 columns]

# %%
grain_df['name'] = [g.replace('-', ' ') for g in grain_df['name']]

# %%
grain_df.shape
# Out:
# (5348, 5)

# %%
grain_df.drop_duplicates(inplace=True)

# %%
[g for g in grain_df['name'].unique() if '2 Row' in g]
# Out:
# ['2 Row Brewers Malt',
#  '2 Row Caramel Malt 40L',
#  'Pale Malt (2 Row) US',
#  '2 Row Caramel Malt 80L',
#  '2 Row (US)',
#  'Great Western Premium 2 Row Malt',
#  '2 Row Caramel Malt 60L',
#  'Château Pilsen 2 Row',
#  'Pale Malt, 2 Row, UK',
#  'Pale Malt, 2 Row, Bel',
#  'American 2 Row',
#  'Château Pale Ale 2 Row',
#  '2 Row Caramel Malt 10L',
#  '2 Row Black Malt',
#  '2 Row Chocolate Malt',
#  'Pilsner (2 Row) UK',
#  'Pale Malt, 2 Row, US',
#  'Mild Ale (2 Row Barley Malt)',
#  'Canada Malting Canadian 2 Row',
#  '2 Row Carapils®\xa0Malt',
#  '2 Row Pale Malt',
#  'Briess 2 Row Pale Malt',
#  'Pale Malt (2 Row) UK',
#  'Canada M.C. Canadian 2 Row',
#  'Canadian 2 Row Malt',
#  'Pale 2 Row (UK)',
#  'Pale Malt (2 Row) South Africa',
#  'Premium 2 Row Malt',
#  'Pale 2 Row (CA)',
#  'Pale 2 Row (US)',
#  'Pilsner (2 Row) Bel',
#  '2 Row Caramel Malt 120L',
#  'Caragill 2 Row',
#  'Château Vienna 2 Row',
#  'Organic 2 Row',
#  "2 Row Brewer's Malt",
#  'Great Western Organic California Select 2 Row',
#  '2 Row Pale',
#  'Prairie Malt Pale 2 Row',
#  'Malteurop American 2 Row',
#  'Malteurop American 2 Row Roasted DARK',
#  'Malteurop American 2 Row Toasted',
#  'US 2 Row Malt',
#  '2 Row Caramel Malt 30L',
#  'Château Munich Light® 2 Row',
#  'Cara Pils 2 Row Barley malt',
#  'Valley Malt 2 Row Pale Malt',
#  'Briess 2 Row Brewers Malt',
#  'Pale 2 Row   Toasted (US)',
#  'Valley Malt 2 Row',
#  '2 Row',
#  'Pale Malt (Rahr 2 Row) US',
#  '2 Row Caramel Malt 15L',
#  'Pilsner (2 Row) Ger',
#  'Pale Malt (2 Row) Bel',
#  'Pale 2 Row',
#  'Brewers Malt 2 Row (Briess)',
#  'Rahr 2 Row Malt',
#  '2 Row (US), Organic',
#  '2 Row Pale Ale Malt',
#  'Great Western 2 Row (US)',
#  'Riverbend 2 Row',
#  '2 Row (US) (Briess)',
#  '2 Row (Epiphany Craft Malt)',
#  '2 Row (GR)',
#  '2 Row (OiO)',
#  'NY State 2 Row (US)',
#  'Briess 2 Row (US)',
#  'Pale Ale Malt 2 Row (Briess)',
#  '2 Row Malt (CA)',
#  '2 Row (US) (Rahr)',
#  'Briess   2 Row Brewers Malt',
#  'Harrington 2 Row',
#  'Pacific Northwest Premium 2 Row',
#  'Home Toasted 2 Row',
#  '2 Row (US) Great Western',
#  '2 Row (US)https://www.brewtoad.com/recipes/chocolate stout 88bbc6/edit#',
#  'Canadian 2 Row',
#  '2 Row (US) Lamonta',
#  'California Select 2 Row',
#  'American 2 Row Base',
#  "Brewer's Malt, 2 Row, Premium (Great Western)",
#  'Black Malt   2 Row (Briess)',
#  '2 Row Malt (Canada Malting Co)',
#  '2 Row (OiO   G&P)',
#  'Pale Ale 2 Row (UK)',
#  '2 Row Caramel Malt 80L   (JW Cara Malt)',
#  'Mesquite 2 Row (US)',
#  '2 Row (Canada Malting Co)',
#  'Rahr 2 Row (US)',
#  'Pale 2 Row  viking',
#  '2 Row (CA)',
#  '2 Row Base',
#  'Golden Promise (2 Row) UK',
#  'Rahr 2 Row',
#  'Rahr Pale 2 Row (UK)',
#  '2 Row (Rahr)',
#  'Gladfield American Ale 2 Row',
#  '2 Row (US, Colorado)',
#  'Maris Otter Pale (UK) or any 2 Row',
#  'Proximity Pale 2 Row (US)',
#  '2 Row Brewers Malt (US)',
#  '2 Row Chocolate Malt1',
#  'Pale 2 Row (US) (Lamonta)',
#  'Canadian 2 Row Malt (OiO)',
#  'Munich 2 Row',
#  '2 Row (US, Briess)',
#  '2 Row Crystal Malt 120L',
#  'GWM Pale Malt (2 Row) US',
#  'GWM Superior Pilsen (2 Row) US',
#  '2 Row Malt',
#  '2 Row Brewers Malt   Saves',
#  'Pale 2 Row (NZ)',
#  'Organic 2 Row (US)',
#  '2 Row (US) Full Pint Malt',
#  '2 Row (Clear Choice) (US)',
#  '2 Row Malt (OiO)',
#  '2 Row   Harvest Malt Guelph',
#  '2 Row (Clear Choice)',
#  'Caramelized 2 Row Wort (US)',
#  'Great Western PNW 2 Row',
#  '2 Row Caramel Malt 20L',
#  '2 Row Vienna',
#  '2 Row (Valley Malt)',
#  '2 Row (Ontario Select)']

# %%
[g.replace('Brewer')]

# %%
grain_df.drop('maltster', axis=1).drop_duplicates().shape
# Out:
# (4317, 4)

# %%
grain_names = grain_df['name'].unique()
sorted(grain_names)
# Out:
# ['',
#  "'s Light Munich",
#  '(Home)Toasted Pale Malt',
#  '(White) Wheat Malt (DE)',
#  '--deleted ingredient--',
#  '.1',
#  '15-Minute Home Toasted Pale Ale Malt (UK)',
#  '2 Row',
#  '2 Row (OiO - G&P)',
#  '2 Row Base',
#  '2 Row Black Malt',
#  '2 Row Pale',
#  '2 Row Pale Malt',
#  '2 Row Vienna',
#  '2 row pale ale malt',
#  '2-Row',
#  '2-Row (CA)',
#  '2-Row (Canada Malting Co)',
#  '2-Row (Clear Choice)',
#  '2-Row (Clear Choice) (US)',
#  '2-Row (Epiphany Craft Malt)',
#  '2-Row (GR)',
#  '2-Row (OiO)',
#  '2-Row (Ontario Select)',
#  '2-Row (Rahr)',
#  '2-Row (US)',
#  '2-Row (US) (Briess)',
#  '2-Row (US) (Rahr)',
#  '2-Row (US) Full Pint Malt',
#  '2-Row (US) Great Western',
#  '2-Row (US) Lamonta',
#  '2-Row (US), Organic',
#  '2-Row (US)https://www.brewtoad.com/recipes/chocolate-stout-88bbc6/edit#',
#  '2-Row (US, Briess)',
#  '2-Row (US, Colorado)',
#  '2-Row (Valley Malt)',
#  '2-Row - Harvest Malt Guelph',
#  '2-Row Black Malt',
#  "2-Row Brewer's Malt",
#  '2-Row Brewers Malt',
#  '2-Row Brewers Malt (US)',
#  '2-Row Brewers Malt - Saves',
#  '2-Row Caramel Malt 10L',
#  '2-Row Caramel Malt 120L',
#  '2-Row Caramel Malt 15L',
#  '2-Row Caramel Malt 20L',
#  '2-Row Caramel Malt 30L',
#  '2-Row Caramel Malt 40L',
#  '2-Row Caramel Malt 60L',
#  '2-Row Caramel Malt 80L',
#  '2-Row Caramel Malt 80L - (JW Cara Malt)',
#  '2-Row Carapils®\xa0Malt',
#  '2-Row Chocolate Malt',
#  '2-Row Chocolate Malt1',
#  '2-Row Crystal Malt 120L',
#  '2-Row Malt',
#  '2-Row Malt (CA)',
#  '2-Row Malt (Canada Malting Co)',
#  '2-Row Malt (OiO)',
#  '2-Row Pale',
#  '2-Row Pale Ale Malt',
#  '2-Row Pale Malt',
#  '2-row',
#  '2-row Pale',
#  '2-row Washington Select Pale Malt',
#  '2-row pale malt',
#  '2-row pilsen',
#  '2/6-Row (MX)',
#  '2013 Cider',
#  '3 gal apple juice',
#  '30-Minute Home Toasted Pale Ale Malt (UK)',
#  '40L Caramel Malt',
#  '6 row',
#  '6-Row (US)',
#  '6-Row (vienna)',
#  '6-Row Brewers Malt',
#  'Abbey Malt',
#  'Abbey Malt  (BE)',
#  'Abbey Malt  (DE)',
#  'Abbey Malt®',
#  'Acid Malt',
#  'Acidulated',
#  'Acidulated (Weyermann)',
#  'Acidulated Malt',
#  'Acidulated Malt (DE)',
#  'Acidulated Malt (DE)4',
#  'Acidulated Malt (PL)',
#  'Acorn Meal',
#  'Admiral Red',
#  'Agave',
#  'Agave Nectar',
#  'Agave Syrup, Blue',
#  'Agave Syrup, Pale',
#  'Agromalte Pilsen',
#  'Alder & Meat Smoked 6-row',
#  'Alder Munich Light (DE)',
#  'Alderwood Smoked Munich',
#  'Ale Malt',
#  'Ale Malt (Barrett Burston)',
#  'All purpose flour',
#  'Almonds (Crushed)',
#  'Amaranth',
#  'Amber',
#  'Amber (UK)',
#  'Amber 50L',
#  'Amber Belgian Candi Syrup',
#  'Amber Candi Sugar, Homemade',
#  'Amber DME',
#  'Amber Dry Extract',
#  'Amber LME',
#  'Amber Malt',
#  'Amber Malt (Thomas Faucett)',
#  'Amber Malt (UK)',
#  'Amber Unhopped LME',
#  'Ambrosia Rice',
#  'American 2-Row',
#  'American 2-Row Base',
#  'American 2-row',
#  'American 6-Row',
#  'American Ale (NZ)',
#  'American Ale Malt – Gladfield (NZ)',
#  'American Black Barley',
#  'American Black Patent',
#  'American Black Roast',
#  'American Chocolate',
#  'American Crystal 105L',
#  'American Crystal 15L',
#  'American Crystal 20L',
#  'American Crystal 30L',
#  'American Crystal 60L',
#  'American Crystal 90L',
#  'American Crystal Dark - 77L',
#  'American Devil IPA',
#  'American Honey Malt',
#  'American Munich',
#  'American Munich (Light, 8-12L)',
#  'American Two-row Toasted',
#  'American Victory',
#  'American Vienna',
#  'American White Wheat',
#  'American chocolate malt',
#  'American pale 2-row',
#  'American two-row',
#  'Apple Cider',
#  'Apple Cider (3 L)',
#  'Apple Cider (unpasteurized)',
#  'Apple Jacks cereal',
#  'Apple Juice',
#  'Apple Juice 1.050',
#  'Apple Juice Back Add',
#  'Apple Juice Concentrate',
#  'Apricot Puree',
#  'Aroma (BE)',
#  'Aroma 100 MD™',
#  'Aroma 120',
#  'Aroma 150 MD™',
#  'Aromatic',
#  'Aromatic (BE)',
#  'Aromatic Barley Malt',
#  'Aromatic MD™/Amber MD™',
#  'Aromatic Malt',
#  'Aromatic Malt (UK)',
#  'Aromatic Malt (US)',
#  'Aromatic Malt (US) (Malty)',
#  'Aromatic Munich Malt',
#  'Aromatic malt',
#  'Aromatic® (Munich) Malt',
#  'Ashbourne Mild (US)',
#  'Ashburn Mild',
#  'Ashburne®\xa0Mild Malt',
#  'Aurora',
#  'Australian Ale Malt',
#  'Australian Pilsner',
#  'Australian Pilsner (JW Pils)',
#  'Australian Wheat Malt',
#  'Avangard Malz Premium Pilsen Malt',
#  'Avangard Pilsen (GE)',
#  'Avangard Pilsner (DE)',
#  'Avangard Premium Pilsner',
#  'Avangard Premium wheat malt',
#  'BEST CARAMEL HELL MALT',
#  'BEST Pilsner',
#  'BEST Red X (DE)',
#  'BREWFERM Pale-ale',
#  'BREWFERM pils malt',
#  "Baird's Amber Malt",
#  "Baird's Dark Caramalt",
#  "Baird's Golden Promise",
#  'Bairds Carastan',
#  'Bairds Carastan Malt',
#  'Bairds Chocolate Malt',
#  'Bairds Crystal Pale',
#  'Bairds Extra Dark Crystal Malt',
#  'Bairds Light Carastan',
#  'Bairds Light Carstan Malt',
#  'Bairds Munich',
#  'Bairds Pale Chocolate',
#  'Bairds Pale Malt',
#  'Baked Pumpkin Pie',
#  'Baked sweet potato',
#  'Bamberg Rauch (Smoked Beer)',
#  'Bananas',
#  'Barley (Flaked)',
#  'Barley (Roasted)',
#  'Barley, Flaked',
#  'Barley, Flaked ()',
#  'Barley, Flaked (Breiss)',
#  'Barley, Raw',
#  'Barley, Torrefied',
#  'Barn Owl Pale Ale (CA)',
#  'Bavarian Pilsner',
#  'Bavarian Wheat DME',
#  'Bavarian Wheat LME',
#  'Bayer',
#  'Bayer malt',
#  'Beachwood Smoked Malt',
#  'Beechwood Smoked',
#  'Beechwood Smoked Malt (DE)',
#  'Beet Juice',
#  'Belgian Ale Malt',
#  'Belgian Aromatic FrancoBelges',
#  'Belgian Aromatic Malt',
#  'Belgian Biscuit',
#  'Belgian Biscuit Malt',
#  'Belgian Black Malt',
#  'Belgian Black Malt 600L',
#  'Belgian Black Roast',
#  'Belgian Candi 0',
#  'Belgian Candi 180',
#  'Belgian Candi Sugar',
#  'Belgian Candi Sugar - Amber/Brown',
#  'Belgian Candi Sugar - Clear',
#  'Belgian Candi Sugar - Clear/Blond',
#  'Belgian Candi Sugar - Clear/Blond (Post Krausen)',
#  'Belgian Candi Sugar - Dark',
#  'Belgian Candi Sugar - Golden',
#  'Belgian Candi Syrup',
#  'Belgian Candi Syrup - Amber',
#  'Belgian Candi Syrup - Clear',
#  'Belgian Candi Syrup - Clear (Golden)',
#  'Belgian Candi Syrup - D-180',
#  'Belgian Candi Syrup - D-45',
#  'Belgian Candi Syrup - D-90',
#  'Belgian Candi Syrup - D2',
#  'Belgian Candi Syrup - Dark',
#  'Belgian Candi Syrup - Extra Dark',
#  'Belgian Candi Syrup - Golden',
#  'Belgian Candi Syrup A',
#  'Belgian Candi Syrup D-90',
#  'Belgian Candi Syrup, Clear',
#  'Belgian Candi Syrup-Dark',
#  'Belgian Candi Syrup: Blonde',
#  'Belgian CaraMunich',
#  'Belgian CaraVienne',
#  'Belgian CaraVienne 22L',
#  'Belgian Caramel Pils',
#  'Belgian Caramel Pils (Cara 8)',
#  'Belgian Carapils',
#  'Belgian Caravienne',
#  'Belgian Chocolate Malt',
#  'Belgian Clear candy sugar',
#  'Belgian Coffee Light',
#  'Belgian Coffee Malt Light',
#  'Belgian Crystal 8L',
#  'Belgian Dark Candi Sugar D2',
#  'Belgian Dark Candi Syrup',
#  'Belgian Debittered Black Malt',
#  'Belgian Golden Candi Syrup',
#  'Belgian Munich',
#  'Belgian Pale',
#  'Belgian Pale Malt',
#  'Belgian Pale Wheat',
#  'Belgian Pils',
#  'Belgian Pilsen',
#  'Belgian Pilsen Malt',
#  'Belgian Pilsner',
#  'Belgian Pilsner (US)',
#  'Belgian Pilsner Malt',
#  'Belgian Soft Candi Sugar - Brown',
#  'Belgian Special B',
#  'Belgian Special aromatic',
#  'Belgian Two-row Pale',
#  'Belgian Wheat',
#  'Belgian pale malt',
#  'Belgium Biscuit Malt',
#  'Belsolod Base Malt',
#  'Best Chit Malt (DE)',
#  'Best Heidelberg Malt',
#  'Best Malt RED X Maláta',
#  'Best Malz Caramel Malt I',
#  'Best Malz Caramel Malt Light',
#  'Best Malz Caramel Pils',
#  'Best Malz Chit Malt',
#  'Best Malz Munich',
#  'Best Malz Munich Malt (DE)',
#  'Best Malz Pilsner',
#  'Best Malz Pilsner (DE)',
#  'Best Malz Pilsner - Smoked',
#  'Best Malz Red X',
#  'Best Malz Red-X',
#  'Best Malz Smoked Malt',
#  'Best Pale Ale Malt',
#  'Best Pils (DE)',
#  'Best Pilsen',
#  'Best Special X (DE)',
#  'Best Vienna',
#  'BestMalz Pale Ale',
#  'BestMalz Pale Ale (DE)',
#  'Bestmalz Pale Ale',
#  'Bestmalz Red X',
#  "Billington's Light Muscovado",
#  'Birch Syrup',
#  'Biscoff Biscuit',
#  'Biscuit',
#  'Biscuit  Malt',
#  'Biscuit (BE)',
#  'Biscuit Malt',
#  'Biscuit Malt (Pale)',
#  'Biscuit, Mout Roost 50. (Dingemans)',
#  'Biscuit\xa0Malt',
#  'Biscuit® MD™',
#  'Black',
#  'Black (Patent) Malt',
#  'Black Barley',
#  'Black Barley (Roast Barley)',
#  'Black Barley (Stout)',
#  'Black Barley (US)',
#  'Black Barley (US) JW Roast Barley (600 lovibond)',
#  'Black Cherry Juice',
#  'Black Currant Puree (Add in Secondary)',
#  'Black Malt',
#  'Black Malt ()',
#  'Black Malt (BE)',
#  'Black Malt (FIN)',
#  'Black Malt (Simpsons)',
#  'Black Malt (UK)',
#  'Black Malt (US)',
#  'Black Malt - 2-Row (Briess)',
#  'Black Malt, Organic',
#  'Black Malted Barley Flour',
#  'Black Patent',
#  'Black Patent (UK)',
#  'Black Patent (UK).75',
#  'Black Patent (US)',
#  'Black Patent Malt',
#  'Black Pearl (Patagonia)',
#  'Black Rice',
#  'Black Roasted Barley',
#  'Black Rock Light LME (NZ)',
#  'Black Rock Miners Stout',
#  'Black Rock Pale Liquid Extract',
#  'Black Treacle',
#  'Black invert',
#  'Black kiln Malt',
#  'Black malt',
#  'Black rice',
#  'Black treacle',
#  'Blackberries',
#  'Blackberries (Fresh)',
#  'Blackberry Honey',
#  'Blacklands Pale Pilsner',
#  'Blackprinz (US)',
#  'Blackprinz®',
#  'Blackprinz® Malt',
#  'Blackstrap Molasses',
#  'Blackswaen Barley Malt',
#  'Blanc Soft Candi Sugar',
#  'Blue Agave Nectar',
#  'Blueberries',
#  'Blueberry Honey',
#  'Blueberry Puree',
#  'Blueberry juice',
#  'Bohemial Pilsner',
#  'Bohemian Floor Malted Dark',
#  'Bohemian Floor-Malted Dark Malt',
#  'Bohemian Floor-Malted Wheat Malt',
#  'Bohemian Pilsner',
#  'Bohemian Pilsner (DE)',
#  'Bohemian Pilsner Malt',
#  'Bonlander',
#  'Bonlander Munich (US)',
#  'Bonlander® Munich Malt',
#  'Bread Syrup',
#  'Bread Syrup - Amber',
#  'Bread syrup',
#  'Breadsyrup',
#  'Breeston Caramalt',
#  'Breiss 21L (mildly kilned)',
#  'Breiss 6-row Brewers Malt',
#  'Breiss Caramel',
#  'Breiss Dark Chocolate',
#  'Breiss Dark LME',
#  'Breiss Golden Light LME',
#  'Breiss Organic Crystal 60L',
#  'BrewVint Alcohol Boost',
#  "Brewer's Malt, 2-Row, Premium (Great Western)",
#  'Brewers Crystals',
#  'Brewers Malt 2-Row (Briess)',
#  'Brewferm Caramel Colrant E150',
#  'Briess - 2 Row Brewers Malt',
#  'Briess - Wheat Malt, White',
#  'Briess 2 Row Pale Malt',
#  'Briess 2-Row (US)',
#  'Briess 2-Row Brewers Malt',
#  'Briess 2-row Pale',
#  'Briess 20L aromatic Munich (DE)',
#  'Briess Aromatic Malt',
#  'Briess Aromatic Malt (US)',
#  'Briess Brewers Malt (Pilsner)(US)',
#  'Briess Caramel 40L',
#  'Briess Caramel 40L (Carlson)',
#  'Briess Caramel 60L',
#  'Briess Caramel 80 (Carlson)',
#  'Briess Caramel Malt 60L',
#  'Briess Carapils',
#  'Briess Cherry Wood Smoked Malt (US)',
#  'Briess Cherrywood Smoked Malt',
#  'Briess Cherrywood Smoked Malt (US)',
#  'Briess Copper Malt',
#  'Briess Crystal 10L',
#  'Briess Gold Pills Vienna',
#  'Briess Gold Pills Vienna (US)',
#  'Briess Light Roasted Barley',
#  'Briess Pale Ale',
#  'Briess Pale Ale Malt',
#  'Briess Roasted Barley',
#  'Briess Rye Malt',
#  'Briess Smoked Malt (Cherry Wood)',
#  'Briess Victory',
#  'Briess Victory (US)',
#  'Briess Vienna Malt',
#  'Briess lt malt extract',
#  'British Amber',
#  'British Black Patent',
#  'British Brown malt',
#  'British Caramalt',
#  'British Caramalt (Brupaks)',
#  'British Crystal (15)',
#  'British Crystal 135-165L',
#  'British Crystal 135L-165L',
#  'British Crystal 25L',
#  'British Crystal 50-60L',
#  'British Crystal 65L',
#  'British Crystal 70-80L',
#  'British Crystal 70/80',
#  'British Crystal 95-115L',
#  'British Crystal Dark (77)',
#  'British Crystal Extra Dark (120)',
#  'British Crystal Malt 60L',
#  'British Dextrin (Cara-Pils)',
#  'British Golden Promise',
#  'British Lager Two-row',
#  'British Mild Ale Malt',
#  'British Munich',
#  'British Pale',
#  'British Pale Malt',
#  'British Pilsener',
#  'British Roast Barley 625 L',
#  'British Two-row Pale',
#  'Brown',
#  'Brown Malt',
#  'Brown Malt (Swaen)',
#  'Brown Malt (UK)',
#  'Brown Rice',
#  'Brown Rice Syrup',
#  'Brown Rice Syrup 45HM',
#  'Brown Sugar',
#  'Brown Sugar (Dark)',
#  'Brown Sugar Dark',
#  'Brown Sugar, Dark',
#  'Brown Sugar, Golden',
#  'Brown Sugar, Light',
#  'Brown Sugar, light',
#  'Brumalt',
#  'Brun Fonce Soft Candi Sugar',
#  'Buckwheat',
#  'Buckwheat (Kasha)',
#  'Buckwheat Honey',
#  'Buckwheat, Flaked',
#  'Burnt Honey',
#  'Burnt Sugar',
#  'Buscuit Malt',
#  'Butternut Squash',
#  'Butternut Squash (Roasted)',
#  'CARAAMBER®',
#  'CARAAROMA®',
#  'CARABELGE®',
#  'CARABOHEMIAN®',
#  'CARAFA® I',
#  'CARAFA® II',
#  'CARAFA® III',
#  'CARAFA® SPECIAL I (Dehusked Barley)',
#  'CARAFA® SPECIAL II (Dehusked Barley)',
#  'CARAFA® SPECIAL III (Dehusked Barley)',
#  'CARAHELL®',
#  'CARAMALT 30 EBC Thomas Fawcett & Sons',
#  'CARAMUNICH® I',
#  'CARAMUNICH® II',
#  'CARAMUNICH® III',
#  'CARAPILS®',
#  'CARARED®',
#  'CARARYE®',
#  'CARAWHEAT®',
#  'CARAWHEAT® Caramel Wheat Malt',
#  'CASTLE BISCUIT MALT',
#  'CBW Golden Light',
#  'CBW Munich LME',
#  'CBW Pilsen Light',
#  'CBW Pilsen Light LME',
#  'CHÂTEAU PILSEN 2RS',
#  'CRISP CRYSTAL MALT 100',
#  'Cabernet Sauvignon',
#  'Cacao Nibs',
#  'Cactus Honey',
#  'Café (BE)',
#  'Cal Rose Rice',
#  'California Select',
#  'California Select 2-Row',
#  'California-Select Organic Pale Malt',
#  'Calrose Rice',
#  'Canada',
#  'Canada M.C. Canadian 2-Row',
#  'Canada Malting Canadian 2-Row',
#  'Canada Malting Company White Wheat',
#  'Canada Malting Superior Pale',
#  'Canada Malting Superior Pale Ale Malt',
#  'Canada Malting Superior Pilsen',
#  'Canadian 2-Row',
#  'Canadian 2-Row Malt',
#  'Canadian 2-Row Malt (OiO)',
#  'Canadian 6-row barley',
#  'Canadian Malting 6-Row',
#  'Canadian Malting Superior Pilsen',
#  'Canadian Two-Row Malt',
#  'Candi Sugar Soft, Brown',
#  'Candi Sugar Syrup, Dark',
#  'Candi Sugar, Amber',
#  'Candi Sugar, Clear',
#  'Candi Sugar, Dark',
#  'Candi Sugar, Homemade',
#  'Candi Sugar, Light',
#  'Candi Syrup 90',
#  'Candi Syrup D-180',
#  'Candi Syrup D-45',
#  'Candi Syrup D-90',
#  'Candi Syrup Simplicity',
#  'Candi syrup Amber',
#  'Candied Ginger',
#  'Candy Sugar',
#  'Cane Sugar',
#  'Cane Sugar (at high krausen)',
#  'Cane/Beet Sugar (Dextrose)',
#  'Canned Hominy, rinsed',
#  'Canned Pumpkin',
#  'Cara 20',
#  'Cara 20 MD™',
#  'Cara 20L (BE)',
#  'Cara 45',
#  'Cara 45L (BE)',
#  'Cara 50 MD™',
#  'Cara 8 (BE)',
#  'Cara 8 (Cara-Pils)',
#  'Cara 8 malt',
#  'Cara Aroma',
#  'Cara Aromatic',
#  'Cara Belge',
#  'Cara Blond',
#  'Cara Blond (BE)',
#  'Cara Blond 20',
#  'Cara Extra Dark',
#  'Cara Gold',
#  'Cara Gold (BE)',
#  'Cara Gold (UK)',
#  'Cara Malt',
#  'Cara Malt (UK)',
#  'Cara Pale (Viking)',
#  'Cara Pils 2 Row Barley malt',
#  'Cara Plus',
#  'Cara Plus 10',
#  'Cara Red (BE)',
#  'Cara Ruby',
#  'Cara Rye',
#  'Cara extra dark',
#  'Cara-Pils',
#  'Cara-Pils/Dextrine',
#  'Cara-crystal 120 EBC',
#  'CaraAmber',
#  'CaraAmber (DE)',
#  'CaraAroma',
#  'CaraAroma (DE)',
#  'CaraAroma (DE) 340-450 EBC',
#  'CaraBelge (DE)',
#  'CaraBelge / Carahell / Cara 20',
#  'CaraBohemian',
#  'CaraBohemian (DE)',
#  'CaraBrown',
#  'CaraBrown (US)',
#  'CaraCrystal Wheat Malt (US)',
#  'CaraDark',
#  'CaraFoam',
#  'CaraFoam (DE)',
#  'CaraGold',
#  'CaraHell',
#  'CaraHell (DE)',
#  'CaraHell (DE) - Caramalt from Beerguevara',
#  'CaraMalt',
#  'CaraMunich',
#  'CaraMunich (BE)',
#  'CaraMunich I',
#  'CaraMunich I (DE)',
#  'CaraMunich II',
#  'CaraMunich II (DE)',
#  'CaraMunich II (DE) 110-130 EBC',
#  'CaraMunich II (Type 2) (German)',
#  'CaraMunich III',
#  'CaraMunich III (DE)',
#  'CaraMunich III (Weyermann)',
#  'CaraPils',
#  'CaraRed',
#  'CaraRed (DE)',
#  'CaraRuby',
#  'CaraRye',
#  'CaraVienne',
#  'CaraVienne (BE)',
#  'CaraVienne (US)',
#  'CaraWheat',
#  'CaraWheat (DE)',
#  'Caraamber',
#  'Caraaroma',
#  'Caraaroma (Weyermann)',
#  'Carabelge',
#  'Carablonde 9L',
#  'Carabrown®\xa0Malt',
#  'Caracrystal®\xa0Wheat Malt',
#  'Carafa I',
#  'Carafa I (DE)',
#  'Carafa I, Dehusked',
#  'Carafa II',
#  'Carafa II (DE)',
#  'Carafa II (DE) dehusked',
#  'Carafa III',
#  'Carafa III (DE)',
#  'Carafa III (DE) Dehusked',
#  'Carafa III (DE)http://www.brewtoad.com/recipes/dark-season/edit#',
#  'Carafa III (Mashout)',
#  'Carafa III Special',
#  'Carafa Special I',
#  'Carafa Special I (DE)',
#  'Carafa Special II',
#  'Carafa Special II (Dehusked)',
#  'Carafa Special II (Weyermann)',
#  'Carafa Special II 1100 EBC',
#  'Carafa Special II 415L',
#  'Carafa Special III',
#  'Carafa Special III (DE)',
#  'Carafa Special Type 3',
#  'CarafaZ',
#  'Carafoam',
#  'Caragill 2-Row',
#  'Carahell',
#  'Caramalt',
#  'Caramalt ()',
#  'Caramalt (UK)',
#  'Caramalt Zahlinice',
#  'Caramel',
#  'Caramel - English Medium',
#  'Caramel / Crystal 10L',
#  'Caramel / Crystal 120L',
#  'Caramel / Crystal 40L',
#  'Caramel / Crystal 60L',
#  'Caramel / Crystal 75L',
#  'Caramel / Crystal 80L',
#  'Caramel 120EBC',
#  'Caramel 20L',
#  'Caramel 40',
#  'Caramel 40L',
#  'Caramel 40L (Briess)',
#  'Caramel 60L',
#  'Caramel 75',
#  'Caramel 80L',
#  'Caramel Coloring',
#  'Caramel Malt - 20L (Briess)',
#  'Caramel Malt - 40L (Briess)',
#  'Caramel Malt - 60L (Briess)',
#  'Caramel Malt - 60L 6-Row (Briess)',
#  'Caramel Malt - 80L 6-Row (Briess)',
#  'Caramel Malt 10L',
#  'Caramel Malt 120',
#  'Caramel Malt 120L',
#  'Caramel Malt 15L',
#  'Caramel Malt 20L',
#  'Caramel Malt 25 (EBC 50)',
#  'Caramel Malt 40L',
#  'Caramel Malt 45L',
#  'Caramel Malt 60L',
#  'Caramel Malt 80L',
#  'Caramel Malt 90L',
#  'Caramel Malt dark II (Crystal Malt)',
#  'Caramel Munich 120L',
#  'Caramel Munich 120L (US)',
#  'Caramel Munich 60L',
#  'Caramel Munich 60L (US)',
#  'Caramel Munich Barley Malt',
#  'Caramel Pils',
#  'Caramel Pils (BE)',
#  'Caramel Pils (DE)',
#  'Caramel Pils (DE)  (Cara Blonde Malt from Beerguevara)',
#  'Caramel Rye',
#  'Caramel Rye (DE)',
#  'Caramel Rye (UK)',
#  'Caramel Vienne',
#  'Caramel Vienne 20L',
#  'Caramel Wheat (DE)',
#  'Caramel Wheat Malt',
#  'Caramel malt',
#  'Caramel/Crystal 10L (US)',
#  'Caramel/Crystal 120L (US)',
#  'Caramel/Crystal 150L (US)',
#  'Caramel/Crystal 15L (US)',
#  'Caramel/Crystal 200',
#  'Caramel/Crystal 20L (US)',
#  'Caramel/Crystal 20L (US) - Simpsons',
#  'Caramel/Crystal 20L (US), Organic',
#  'Caramel/Crystal 30L (US)',
#  'Caramel/Crystal 40',
#  'Caramel/Crystal 40 L (US)',
#  'Caramel/Crystal 40L (US)',
#  'Caramel/Crystal 40L (US) (Sweet and Caramel)',
#  'Caramel/Crystal 45L',
#  'Caramel/Crystal 45L (Muntons)',
#  'Caramel/Crystal 50 EBC (FI)',
#  'Caramel/Crystal 50-60L (UK)',
#  'Caramel/Crystal 60L',
#  'Caramel/Crystal 60L (US)',
#  'Caramel/Crystal 75L (GB)',
#  'Caramel/Crystal 75L (US)',
#  'Caramel/Crystal 77L (UK)',
#  'Caramel/Crystal 77L (US)',
#  'Caramel/Crystal 80L (GB)',
#  'Caramel/Crystal 80L (US)',
#  'Caramel/Crystal 90L (US)',
#  'Caramel/Crystal Malt - 100L',
#  'Caramel/Crystal Malt - 10L',
#  'Caramel/Crystal Malt - 120L',
#  'Caramel/Crystal Malt - 15L',
#  'Caramel/Crystal Malt - 20L',
#  'Caramel/Crystal Malt - 30L',
#  'Caramel/Crystal Malt - 40L',
#  'Caramel/Crystal Malt - 45L',
#  'Caramel/Crystal Malt - 50L',
#  'Caramel/Crystal Malt - 60L',
#  'Caramel/Crystal Malt - 70L',
#  'Caramel/Crystal Malt - 80L',
#  'Caramel/Crystal Malt -120L',
#  'Caramel/Crystal Malt 120L (US)',
#  'Caramel250 (RUS)',
#  'Caramelized 2-Row Wort (US)',
#  'Caramelized Wort, Last runnings',
#  'Caramelo',
#  'Caramunch Caramel Malt',
#  'Caramunich',
#  'Caramunich I',
#  'Caramunich I (Weyermann)',
#  'Caramunich II',
#  'Caramunich III',
#  'Caramunich Malt',
#  'Caramunich Malt 20',
#  'Caramunich Malt 40',
#  'Caramunich Malt 45',
#  'Caramunich Malt 60',
#  'Carapale (Viking)',
#  'Carapils',
#  'Carapils (Briess)',
#  'Carapils (DE)',
#  'Carapils (Dextrine Malt)',
#  'Carapils (Dextrine Malt) (US)',
#  'Carapils Copper',
#  'Carapils Malt',
#  'Carapils®\xa0Malt',
#  'Caraplus 150 (FI)',
#  'Carared',
#  'Cararye',
#  'Carastan',
#  'Carastan (US)',
#  'Carastan 30L (UK)',
#  'Carastan Light 15L (UK)',
#  'Carastan Malt',
#  'Caravienne',
#  'Caravienne Malt',
#  'Carawheat',
#  'Cargill Caramel 10L',
#  'Cargill IdaPils',
#  'Cargill Idapils',
#  'Cargill Munich Malt',
#  'Cargill Special Pale',
#  'Cargill White Wheat',
#  'Carob Molasses',
#  'Carrots',
#  'Cascade Beer Candi Syrup-Cocoa Nibs',
#  'Cascade tart cherry Belgian Candi Sugar - Clear/Blond',
#  'Castle Abbey (Amber 45)',
#  'Castle Aroma',
#  'Castle Belgian Pilsner Malt',
#  'Castle Belgian biscuit malt',
#  'Castle Biscuit',
#  'Castle Black Malt',
#  'Castle Cara Blond',
#  'Castle Cara Blond (Cara 20)',
#  'Castle Cara Gold (Cara 120)',
#  'Castle Cara Ruby (Cara 50)',
#  'Castle Caramunich',
#  'Castle Caravienne',
#  'Castle Chocolate',
#  'Castle Château Cara Ruby (BE)',
#  'Castle Coffee Light',
#  'Castle Coffee Malt',
#  'Castle Crystal',
#  'Castle Crystal (Cara 150)',
#  'Castle Melano Light (45 EBC)',
#  'Castle Melanoidin (80 EBC)',
#  'Castle Munich (25 EBC)',
#  'Castle Munich Light (15 EBC)',
#  'Castle Munich Wheat',
#  'Castle Pale Ale',
#  'Castle Peated (Smoked)',
#  'Castle Pilsen 2RS',
#  'Castle Pilsen 2RS (BE)',
#  'Castle Rye',
#  'Castle Special B',
#  'Castle Special B Malt',
#  'Castle Vienna',
#  'Castle Wheat',
#  'Castle Wheat Blanc',
#  'Castle aromatic malt',
#  'Chancaca Sugar',
#  'Chateau - Cara Crystal',
#  'Chateau Biscuit (BE)',
#  'Chateau Cara Ruby 20L',
#  'Chateau CaraRuby 19L',
#  'Chateau Pale Ale',
#  'Cherry Juice',
#  'Cherry Smoked',
#  'Cherry Smoked Malt',
#  'Cherry Wood Smoked Malt (Briess)',
#  'Cherry Wood Smoked Malt (US)',
#  'Cherrywood Smoke Malt',
#  'Cherrywood Smoked Malt',
#  'Cherrywood Smoked Malt (DE)',
#  'Cherrywood Smoked Malt (US)',
#  'Chestnuts',
#  'Chinese Rock Sugar',
#  'Chit Malt',
#  'Chocolate',
#  'Chocolate (AU)',
#  'Chocolate (BE)',
#  'Chocolate (Briess)',
#  'Chocolate (FI)',
#  'Chocolate (UK)',
#  'Chocolate (UK) - TF',
#  'Chocolate (US)',
#  'Chocolate (US) (Bitter and Roasted)',
#  'Chocolate (US).5',
#  'Chocolate 900 EBC',
#  'Chocolate Crisp',
#  'Chocolate Dark Malt – Gladfield (NZ)',
#  'Chocolate Dehusked',
#  'Chocolate Malt',
#  'Chocolate Malt ()',
#  'Chocolate Malt (Gladfields)',
#  'Chocolate Malt (Pale)',
#  'Chocolate Malt (TF) 1200 EBC',
#  'Chocolate Malt (UK)',
#  'Chocolate Malt (UK) (Muntons)',
#  'Chocolate Malt (US)',
#  'Chocolate Malt 525L',
#  'Chocolate Malt(US)',
#  'Chocolate Rye',
#  'Chocolate Rye (DE)',
#  'Chocolate Rye Malt',
#  'Chocolate Rye Malt (Roasted Malt)',
#  'Chocolate Syrup',
#  'Chocolate Wheat',
#  'Chocolate Wheat (DE)',
#  'Chocolate Wheat (Weyermann)',
#  'Chocolate Wheat Malt',
#  'Chocolate Wheat Malt (Roasted Malt)',
#  'Chocolate malt',
#  'Chocolate(Fawcet)',
#  'Chocolate, Pale',
#  'Château Abbey®',
#  'Château Aroma (100 EBC)',
#  'Château Arôme',
#  'Château Biscuit Malt',
#  'Château Biscuit®',
#  'Château Black',
#  'Château Café',
#  'Château Café Light®',
#  'Château Cara Blond®',
#  'Château Cara Gold®',
#  'Château Cara Ruby®',
#  'Château Chocolat',
#  'Château Crystal®',
#  'Château Diastatic',
#  'Château Melano',
#  'Château Melano Light',
#  'Château Munich',
#  'Château Munich Light® 2-Row',
#  'Château Munich Light™',
#  'Château Pale Ale',
#  'Château Pale Ale 2-Row',
#  'Château Pale Ale 6-Row',
#  'Château Peated (Smoked)',
#  'Château Pilsen 2-Row',
#  'Château Pilsen 6-Row',
#  'Château Pilsner Malt',
#  'Château Roasted Barley',
#  'Château Special B®',
#  'Château Vienna 2-Row',
#  'Château Wheat Blanc',
#  'Château Wheat Munich',
#  'Château Wheat®',
#  'Châteazu Wheat Blanc',
#  'Cider',
#  'Cinnamon Toast Crunch Cereal -General Mills',
#  'Clementine Juice',
#  'Clover Honey',
#  'Coco Pebbles Cereal',
#  'Cocoa Nibs',
#  'Cocoa Powder',
#  'Cocoa powder',
#  'Coconut Nectar (Light)',
#  'Coconut Sugar',
#  'Coffee Malt',
#  "Coffee Malt (Simpson's)",
#  'Coffee Malt (UK)',
#  'Coffee espresso',
#  'Coffee malt',
#  'Colorado Two-row Pale',
#  'Condensed wort',
#  'Cookie',
#  "Cooper's Australian Pale Ale",
#  'Coopers Ale Malt',
#  'Coopers Amber malt extract',
#  'Coopers Brewing sugar',
#  'Coopers Dark Ale Kit',
#  'Coopers Dark LME',
#  'Coopers Light LME',
#  'Coopers Plain Light DME',
#  'Coopers Stout Kit',
#  'Copper Malt',
#  'Corn Grits',
#  'Corn Sugar',
#  'Corn Sugar (Dextrose)',
#  'Corn Syrup',
#  'Corn, Flaked',
#  'Cornmeal',
#  'Corsair Toasted Caramel',
#  'Costco Cider',
#  'Cranberry',
#  'Creamy Brown UME',
#  'Crisp Amber',
#  'Crisp Amber (BSG Craft Brewing)',
#  'Crisp Black Patent',
#  'Crisp Brown',
#  'Crisp CaraMalt',
#  'Crisp Chocolate (Crosby/Baker)',
#  'Crisp Chocolate (US)',
#  'Crisp Chocolate Malt',
#  'Crisp Chocolate malt',
#  'Crisp Crystal 15L',
#  'Crisp Crystal 77',
#  'Crisp Crystal 77L (Crosby/Baker)',
#  'Crisp Crystal Malt 120L',
#  'Crisp Crystal Malt 45L',
#  'Crisp Crystal Malt 60L',
#  'Crisp Crystal Malt 77L',
#  'Crisp Dark Crystal',
#  'Crisp Dextrin Malt',
#  'Crisp EURO Pilsner Malt',
#  'Crisp Maris Otter',
#  'Crisp Marris Otter',
#  'Crisp Melanoidin Malt',
#  'Crisp Munich',
#  'Crisp Organic Pale Ale Malt',
#  'Crisp Pale Ale Malt',
#  'Crisp Pale Chocolate Malt',
#  'Crisp Roasted Barley',
#  'Crystal',
#  'Crystal (BE)',
#  'Crystal (Extra Dark)',
#  'Crystal 1 ()',
#  'Crystal 100',
#  'Crystal 100EBC',
#  'Crystal 100L',
#  'Crystal 10L',
#  'Crystal 110',
#  'Crystal 110L',
#  'Crystal 120',
#  'Crystal 120L',
#  'Crystal 120L (CA)',
#  ...]

# %%
hop_list = []
for i in df.loc[:, 'hops'].values:
    for j in i.values():
        temp = j.copy()
        del temp['amount']
        del temp['amount_unit']
        del temp['time']
        del temp['use']
        if temp not in hop_list:
            hop_list.append(temp)
hops = pd.DataFrame(hop_list)
hops
# Out:
#       alpha    form                                            name
# 0     0.150  Pellet                                   Columbus (US)
# 1     0.120  Pellet                                      Citra (US)
# 2     0.130  Pellet                                     Simcoe (US)
# 3     0.120  Pellet                                           Citra
# 4     0.028  Pellet                                       Saaz (CZ)
# 5     0.061  Pellet                                 Tettnanger (DE)
# 6     0.030  Pellet                                       Saaz (CZ)
# 7     0.110  Pellet                                      Citra (US)
# 8     0.050  Pellet                                      Czech Saaz
# 9     0.064  Pellet                                    Cascade (NZ)
# 10    0.180  Pellet                                     Summit (US)
# 11    0.141  Pellet                                      Citra (US)
# 12    0.107  Pellet  3-6-9 Experimental (Simcoe Sister Strain) (US)
# 13    0.130    Leaf                                     Nugget (US)
# 14    0.100    Leaf                                 Centennial (US)
# 15    0.105    Leaf                                 Centennial (US)
# 16    0.087  Pellet                                 Centennial (US)
# 17    0.072  Pellet                                    Motueka (NZ)
# 18    0.118  Pellet                              Nelson Sauvin (NZ)
# 19    0.154    Leaf                                     Galaxy (AU)
# 20    0.089  Pellet                                 Centennial (US)
# 21    0.040  Pellet                                    Cascade (US)
# 22    0.032  Pellet                            Styrian Golding (SI)
# 23    0.150  Pellet                                    Warrior (US)
# 24    0.031  Pellet                                       Saaz (CZ)
# 25    0.130    Leaf                                     Simcoe (US)
# 26    0.045  Pellet                                 Tettnanger (DE)
# 27    0.038  Pellet                                       Saaz (US)
# 28    0.048  Pellet                          East Kent Golding (UK)
# 29    0.058  Pellet                                    Cascade (US)
# ...     ...     ...                                             ...
# 8460  0.234  Pellet                                     Simcoe (US)
# 8461  0.048  Pellet                                      Helga (AU)
# 8462  0.134  Pellet                                    Equinox (US)
# 8463  0.240  Pellet                                    Chinook (US)
# 8464  0.094  Pellet                                         HBC 472
# 8465  0.070    Leaf                                         Cluster
# 8466  0.142  Pellet                                         Chinook
# 8467  0.040  Pellet                                          tahoma
# 8468  0.000  Pellet                                     Saphir (DE)
# 8469  0.093  Pellet                                  Mystery X (US)
# 8470  0.093    Leaf                                  Mystery X (US)
# 8471  0.093    Leaf                        Mystery X (US) - Wet Hop
# 8472  0.120  Pellet                        Mystery X (US) - Wet Hop
# 8473  0.120  Pellet                                  Mystery X (US)
# 8474  0.070    Plug                                    Cascade (US)
# 8475  0.080    Leaf                                  Styrian Aurora
# 8476  0.152  Pellet                             Columbus (Tomahawk)
# 8477  0.050  Pellet                                 Wild Willamette
# 8478  0.060  Pellet                                    Mosaic™ (US)
# 8479  0.099  Pellet                                 Mount Hood (US)
# 8480  0.156  Pellet                                        herkules
# 8481  0.051  Pellet                                     Summer (AU)
# 8482  0.110  Pellet                                            Dana
# 8483  0.186    Plug                                    Warrior (US)
# 8484  0.145  Pellet                                  The Golden Hop
# 8485  0.103  Pellet                               Mandarina Bavaria
# 8486  0.010  Pellet                                          [none]
# 8487  0.029    Plug                                  Hallertau (DE)
# 8488  0.146    Leaf                                      Citra (US)
# 8489  0.090    Leaf                                       Zeus (US)
#
# [8490 rows x 3 columns]

# %%
hop_names = hops['name'].unique()

# %%
citra_hops = [h for h in hop_names if 'citra' in h.lower()]
citra_hops
# Out:
# ['Citra (US)',
#  'Citra',
#  'Citra Cryohop',
#  'Citra Cyro Powder',
#  'Citra (US) [SECONDARY]',
#  'Citra 10;50',
#  'Citra 11:20',
#  'Citra 11;35  (add whirlfloc)',
#  'Citra 11;40 (add YN) get honey ready',
#  'Citra 11;50',
#  'CitraCitra Cryo (Lupulin, 26.00% AA)',
#  'Citra (US) Lupulin',
#  'citra',
#  'Citra Lupulin Powder',
#  'Citra (US)     Dry Hop 3',
#  'Citra (US)     Keg Hop',
#  'Citra (US)     Dry Hop 1',
#  'Citra (US)l',
#  'Citra (US) Cryo']

# %%
sorted(hop_names)
# Out:
# ['(00) Amarillo - chill cube*',
#  '(00) Cascade - chill cube*',
#  '(00) Simcoe - chill cube*',
#  '(05) Cascade - 70c in cube',
#  '(05) Simcoe - 70c in cube',
#  '(10) Cascade - in cube',
#  '(10) Simcoe - in cube',
#  '(15) Cascade - 5m',
#  '(15) Simcoe - 5m',
#  '(dh) Amarillo - Dry hop, split over two additions',
#  '(dh) Cascade - Dry hop, amount split over two additions',
#  '(dh) Simcoe - Dry hop, split over two additions',
#  '--deleted ingredient--',
#  '007',
#  '007 Golden Hop Hash',
#  '007 The Golden Hop',
#  '007 The Golden Hop Hash',
#  '007: Golden Hop',
#  '04190',
#  '070',
#  '14 saaz us',
#  '14 saaz usa',
#  '2013 Cascade',
#  '2014 Lemondrop',
#  '3 Year Aged Goldings',
#  '3-6-9 Experimental (Simcoe Sister Strain)',
#  '3-6-9 Experimental (Simcoe Sister Strain) (US)',
#  '3-6-9 Experimental (Simcoe Sister Strain) aka Mosaic',
#  '3:20pm Saaz (US)',
#  '3:50pm Saaz (US)',
#  '4190',
#  '4:05 pm WFL + YN (5 min later) + Saaz (US)',
#  '58-4',
#  "7 C's Centennial Blend",
#  "7C's",
#  "7C's (US)",
#  "7C's Falconer's Flight (US)",
#  "7c's",
#  '95u',
#  '95u1',
#  '95u1/108',
#  '98x',
#  'AB Experimental (US)',
#  'ADHA 424',
#  'ADHA 529',
#  'ADHA 881 (2013 Yakima experimental)',
#  'ADHA-484',
#  'ADHA-527',
#  'Admiral (UK)',
#  'African Queen',
#  'African Queen J17',
#  'Aged / Debittered Hops (Lambic)',
#  'Aged Fuggle',
#  'Aged Hops',
#  'Aged Hops (US)',
#  'Aged Lambic',
#  'Aged Lambic Hops 3 years',
#  'Aged T-90',
#  'Aged Willamette',
#  'Aged Willamette (US)',
#  'Ahtanum',
#  'Ahtanum (US)',
#  'Ales for ALS',
#  'Alpharoma',
#  'Alta (UA)',
#  'Amalia',
#  'Amalia (Neomexicanus)',
#  'Amaraillo',
#  'Amarillo',
#  'Amarillo (67%)/Simcoe (20%)/Warrior (13%)',
#  'Amarillo (US)',
#  'Amarillo (US) or Galaxy (AU)',
#  'Amarillo / Yellow hub',
#  'Amarillo Gold',
#  'Amarillo Hop Hash',
#  'American Bravo (US)',
#  'American Summit',
#  'Aparacio Farm Wild Hop',
#  'Apollo',
#  'Apollo (US)',
#  'Apollo Extract',
#  'Apricot Puree',
#  'Aquila',
#  'Aramis',
#  'Aramis (FR)',
#  'Archer (UK)',
#  'Argentine Cascade',
#  'Argentinian Cascade',
#  'Ariana',
#  'Atlas',
#  'Aurora',
#  'Aurora (SI)',
#  'Aurora (Super Styrian)',
#  'Aurora Slovenia',
#  'Aurora Slovenian',
#  'Auscha (Saaz)',
#  'Australian Galaxy',
#  'Australian Summer',
#  'Australian Super Pride',
#  'Azaaca',
#  'Azaca (US)',
#  'Azacca',
#  'Azacca (DH2)',
#  'Azacca (NZ)',
#  'Azacca (US)',
#  'Azacca DH1',
#  'Azacca DH2',
#  'Azacca mine',
#  'Azacca(US)',
#  'Azzaca',
#  'Azzacca',
#  'BELMA',
#  'BIC hop',
#  'Backyard Blend',
#  'Banner',
#  'Barberouge',
#  'Bavaria Mandarina (DE)',
#  'Beardale Mystery Hop',
#  'Beata',
#  'Belgian Cascade',
#  'Bellma',
#  'Belma',
#  'Belma (US)',
#  'Belma (add YN) get honey ready',
#  'Belma (add whirlfloc)',
#  'Belma 2-399-303',
#  'Belma: Pellet (US)',
#  'Bianca',
#  'Bitter Gold',
#  'Bittering Hops 17%AA',
#  'Blackhawk',
#  'Blanc',
#  'Blato',
#  'Blend A',
#  'Blend B',
#  'Boadicea',
#  'Boadicea (US)',
#  'Bobek',
#  'Bor',
#  'Bramling Cross (UK)',
#  'Bravo',
#  'Bravo (US)',
#  'Bravo Hops (US)',
#  "Brewer's Gold",
#  'Brewers Gold',
#  'Brewers Gold (DE)',
#  'Brewers Gold (US)',
#  'Brooklyn',
#  'Bru-1',
#  'Bullion (DE)',
#  'C-Hop blend (HopUnion)',
#  'CF115',
#  'CTZ',
#  'CTZ (Columbus/Tomahawk/Zeus) (US)',
#  'CTZ (US)',
#  'CTZ - Columbus/Tomahawk/Zeus (US)',
#  'Calienta',
#  'Caliente',
#  'Caliente (US)',
#  'California Ivanhoe',
#  'Calypso',
#  'Calypso (US)',
#  'Canadian Red Vine',
#  'Canadian red vine',
#  'Cascade',
#  'Cascade (CA)',
#  'Cascade (Ch)',
#  'Cascade (Fresh)',
#  'Cascade (Homegrown)',
#  'Cascade (Homegrown, Fresh)',
#  'Cascade (MBs)',
#  'Cascade (NE)',
#  'Cascade (NZ)',
#  'Cascade (QC)',
#  'Cascade (Trauty)',
#  'Cascade (U..)',
#  'Cascade (UK)',
#  'Cascade (US)',
#  'Cascade (US) (blomst)',
#  'Cascade (US) (hop rocket 2)',
#  'Cascade (US) (hop rocket)',
#  'Cascade (US) DH2',
#  'Cascade (US) FRESH Hops',
#  'Cascade (US) Hop Rocket',
#  'Cascade (US) Keg',
#  'Cascade (US) Keg Hop',
#  'Cascade (US) hop rocket',
#  'Cascade (US) in 1o',
#  'Cascade (Wet)',
#  'Cascade (Xinjiang)',
#  'Cascade (us)',
#  'Cascade - Dried, 5.5',
#  'Cascade - Dry (Baylor)',
#  'Cascade - Fresh',
#  'Cascade - Wet (Vachetto)',
#  'Cascade - wet hop',
#  'Cascade -- fresh, home grown (Wet Hops) (US)',
#  'Cascade 2013',
#  'Cascade Argentino',
#  'Cascade CryoHop',
#  'Cascade Cryohop',
#  'Cascade Hallertau (German)',
#  'Cascade Homegrown',
#  'Cascade Homegrwn',
#  'Cascade/Centennial homegrown',
#  'Caschook (CA)',
#  'Cashmere',
#  'Cashmere (US)',
#  'Celeia',
#  'Centenial',
#  'Centennia1.1l (US)',
#  'Centennial',
#  'Centennial (US)',
#  'Centennial (US) (late)',
#  'Centennial CO2',
#  'Centennial Hop Hash',
#  'Centennial Type',
#  'Centurion (Centennial Type)',
#  'Challenger',
#  'Challenger (MI)',
#  'Challenger (UK)',
#  'Challenger (UK) To 59 IBU',
#  'Chamomile',
#  'Chelan (US)',
#  'Chinese Bittering Hops',
#  'Chinook',
#  'Chinook (Homegrown, Fresh)',
#  'Chinook (MI)',
#  'Chinook (NE)',
#  'Chinook (QC)',
#  'Chinook (US)',
#  'Chinook (US)     Dry Hop 2',
#  'Chinook (US)     Dry Hop 3',
#  'Chinook (US) DH1',
#  'Chinook (US) DH2',
#  'Chinook (US)5',
#  'Chinook Homegrown',
#  'Chinook Qc',
#  'Chocolate Coconut',
#  'Citra',
#  'Citra (US)',
#  'Citra (US)     Dry Hop 1',
#  'Citra (US)     Dry Hop 3',
#  'Citra (US)     Keg Hop',
#  'Citra (US) Cryo',
#  'Citra (US) Lupulin',
#  'Citra (US) [SECONDARY]',
#  'Citra (US)l',
#  'Citra 10;50',
#  'Citra 11:20',
#  'Citra 11;35  (add whirlfloc)',
#  'Citra 11;40 (add YN) get honey ready',
#  'Citra 11;50',
#  'Citra Cryohop',
#  'Citra Cyro Powder',
#  'Citra Lupulin Powder',
#  'CitraCitra Cryo (Lupulin, 26.00% AA)',
#  'Clean out the freezer',
#  'Clone-18 (UA)',
#  'Cluster',
#  'Cluster (CH)',
#  'Cluster (CN)',
#  'Cluster (China)',
#  'Cluster (US)',
#  'Cluster (Xinjiang)',
#  'Columbs 13.8',
#  'Columbus',
#  'Columbus (Green!)',
#  'Columbus (Tomahawk)',
#  'Columbus (US)',
#  'Columbus (US) (late)',
#  'Columbus (US) (pellet)',
#  'Columbus (US) (whole)',
#  'Columbus (US)wp',
#  'Columbus (Wet)',
#  'Columbus(US)',
#  'Columbus/Tom/Zeus',
#  'Comet',
#  'Comet (US)',
#  'Cryo Cascade (US)',
#  'Crystal',
#  'Crystal (US',
#  'Crystal (US)',
#  'Crystal.1',
#  'Ctz',
#  'Cz Permentie',
#  'Cz Permiant',
#  'Czech Saaz',
#  'Czech Saaz alpha 3.0 (SI)',
#  'DELTA',
#  'DR Rudi',
#  'DR. Rudi (NZ)',
#  "Dad's Backyard Cascade (US)",
#  'Dana',
#  'Debittered Hops',
#  'Delta',
#  'Delta (US)',
#  'Denali',
#  'Denali (US)',
#  'Doctor Rudi',
#  'Dr Rudi',
#  'Dr Rudi (NZ)',
#  'Dr Rudi (Super Alpha) (NZ)',
#  'Dr rudi',
#  'Dr. Rudi',
#  'Dr. Rudi (NZ)',
#  'Dr. Rudy',
#  'Dr. rudy',
#  'EK Golding',
#  'EKG',
#  'EQUINOX',
#  'EXP 1210',
#  'EXP 6300',
#  'EXP 6300 (US)',
#  'EXP Grapefruit',
#  'EXP LEMONAUGHTY',
#  'EXP Pinefruit',
#  'EXP4190',
#  'EXP5256',
#  'East Kent',
#  'East Kent Gold',
#  'East Kent Golding',
#  'East Kent Golding (UK)',
#  'East Kent Golding (UK) To 28 IBU',
#  'East Kent Golding (UK) [PRIMARY]',
#  'East Kent Golding (US)',
#  'East Kent Goldings',
#  'East Kent Goldings (ABS)',
#  'East Kent Goldings (EKG)',
#  'East Village Centennial (US)',
#  'Edelweiss',
#  'Ekuanot',
#  'Ekuanot (HBC 366) CryoHop',
#  'Ekuanot (UK)',
#  'Ekuanot (US)',
#  'Ekuanot Cryo',
#  'Ekuanot LupuLN2',
#  'Ekuanot, Cryohop',
#  'El Dorado',
#  'El Dorado (US)',
#  'El Dorado (US) Hash',
#  'El Dorado Hop Hash',
#  'El Dorado hash',
#  'Eldorado',
#  'Eldorado (US)',
#  'Ella',
#  'Ella (AU)',
#  'Ella (Stella) (AU)',
#  'Endeavour (UK)',
#  'Enigma',
#  'Enigma (AU)',
#  'Epic',
#  'Eq',
#  'Equaknot',
#  'Equinox',
#  'Equinox (US)',
#  'Equinox™ (US)',
#  "Erich's Mystery Hop",
#  'Eroica (US)',
#  'Est Kent Golding',
#  'Eukanot',
#  'Eureka',
#  'Eureka!',
#  'Eureka! (US)',
#  'Exp 07270',
#  'Exp 5256',
#  'Exp 6300',
#  'Exp 6300 (US)',
#  'Exp 7270',
#  'Exp Grapefruit',
#  'Exp. 1210 (US)',
#  'Exp. Grapefruit',
#  'Experiment 4190 (US)',
#  'Experimental (US)',
#  'Experimental 07270',
#  'Experimental 07270 (US)',
#  'Experimental 366',
#  'Experimental 946',
#  'Experimental Grapefruit',
#  'Experimental Grapefruit  (US)',
#  'Experimental Grapefruit (YVH)',
#  'Experimental Lemon',
#  'Experimental Pine Fruit',
#  'Experimental Stone Fruit Hops',
#  'Experimental-366',
#  'Expiremental HBC-342(USA)',
#  'Extra Styrian Dana',
#  'Extract',
#  'Extrato de lúpulo',
#  'FRESH Cascade',
#  'FRESH Centennial',
#  'FRESH Columbus',
#  'FRESH Fuggle',
#  'FRESH Galena',
#  'FRESH Magnum',
#  'Fairview Fresh Hop',
#  "Falconer's 7 C's",
#  "Falconer's 7C's",
#  "Falconer's 7Cs",
#  "Falconer's Flight",
#  "Falconer's Flight (US)",
#  "Falconer's Flight 7 C's",
#  "Falconer's Flight 7 C's  (US)",
#  "Falconer's Flight 7 C's (US)",
#  "Falconer's Flight 7C",
#  "Falconer's Flight 7C's",
#  "Falconer's Flight 7C's (US)",
#  "Falconer's Flight 7Cs (US)",
#  "Falconer's Seven Seas",
#  "Falconers 7 C's",
#  'Falconers Flight',
#  'Falconers Flight (US)',
#  'Fantasia',
#  'Fence',
#  'First Gold (UK)',
#  "Flaconer's Flight (US)",
#  'Flyer',
#  'Flyer (UK)',
#  'Francii',
#  'French Aramis',
#  'French Strisselspalt',
#  'Fresh Cascade',
#  'Fresh Centennial',
#  'Fresh Columbus Hops',
#  'Fresh Hop',
#  'Freshly picked Cascade',
#  'Freshly picked Fuggle?',
#  'Front fence hops',
#  'Fuggle',
#  'Fuggle (NZ)',
#  'Fuggle (UK)',
#  'Fuggle (US)',
#  'Fuggle (Wet)',
#  'Fuggle WHS',
#  'Fuggles',
#  'GB Mystery Hop',
#  'Galaxy',
#  'Galaxy (AU)',
#  'Galaxy (AU)     Dry Hop 1',
#  'Galaxy (AU)     Dry Hop 2',
#  'Galaxy (AU)     Keg Hop',
#  'Galaxy (AU) (DH1)',
#  'Galaxy (AU) (DH2)',
#  'Galaxy (AU) (DH3)',
#  'Galaxy (AU) (DH4)',
#  'Galaxy (AU) (hop rocket 2)',
#  'Galaxy (AU) (hop rocket)',
#  'Galaxy (AU) DH 1',
#  'Galaxy (AU) DH 2',
#  'Galaxy (AU) DH1',
#  'Galaxy (AU) DH2',
#  'Galaxy (AU) Keg',
#  'Galaxy (AU) Keg Hop',
#  'Galaxy (AU) Whirlpool',
#  'Galaxy (AU)wp',
#  'Galaxy (US)',
#  'Galena',
#  'Galena (Homegrown)',
#  'Galena (NE)',
#  'Galena (US)',
#  'Garden Mix (US)',
#  'German Blanc',
#  'German Hallertau',
#  'German Hallertau Blanc',
#  'German Hallertauer Hersbrucker',
#  'German Huell Melon',
#  'German Hull Melon',
#  'German Hull melon',
#  'German Magnum',
#  'German Magnum (DE)',
#  'German Mandarina Bavaria',
#  'German Merkur',
#  'German Northern Brewer (DE)',
#  'German Perle',
#  'German Perle (DE)',
#  'German Smaragd (DE)',
#  'German Spalt',
#  'German Spalt Select (DE)',
#  'German Tettnang',
#  'German northern Brewer',
#  'Glacier',
#  'Glacier (US)',
#  'Golden hops 007',
#  'Golding',
#  'Golding (UK)',
#  'Golding (US)',
#  'Golding 5%',
#  "Golding Marc's Mystery Hops",
#  "Golding Marc's mystery hops",
#  'Goldings',
#  'Goldings (Kent)',
#  'Goldings, B.C.',
#  'Goldings, East Kent',
#  'Goldings, East Kent (UK)',
#  'Gordons hop extract (CA)',
#  'Grapefruit',
#  'Green Bullet',
#  'Green Bullet  (NZ)',
#  'Green Bullet (NZ)',
#  'Green Machine',
#  'Green Magic',
#  'Green bullet',
#  'Groene Bel',
#  'Guest Hop',
#  'HBC 342',
#  'HBC 342  (US)',
#  'HBC 342 (US)',
#  'HBC 342 Experimental',
#  'HBC 366',
#  'HBC 366 (US)',
#  'HBC 438',
#  'HBC 438 [Ron Mexico] (US)',
#  'HBC 472',
#  'HBC 682',
#  'HBC-342',
#  'HBC-342 (US)',
#  'HBC-472',
#  'HBC342',
#  'HBC342 Experimental',
#  'HBC438',
#  'HBC462',
#  'HCB 438',
#  'HHF Saaz',
#  'HM (DE)',
#  'HOP SHOT',
#  'Haga, Sweden',
#  'Halleratau Blanc',
#  'Hallertau',
#  'Hallertau (DE)',
#  'Hallertau (US)',
#  'Hallertau (Wakatu)',
#  'Hallertau Blac',
#  'Hallertau Blanc',
#  'Hallertau Blanc (DE)',
#  'Hallertau DE (YCH)',
#  'Hallertau Gold (DE)',
#  'Hallertau Magnun T-90',
#  'Hallertau Mitt',
#  'Hallertau Mittelfru',
#  'Hallertau Perle',
#  'Hallertau Perle (DE)',
#  'Hallertau Tradition',
#  'Hallertau blanc',
#  'Hallertauer',
#  'Hallertauer  (DE)',
#  'Hallertauer (German)',
#  'Hallertauer Aroma (NZ)',
#  'Hallertauer Aroma (NZ) (Wakatu)',
#  'Hallertauer Aroma (Wakatu) (NZ)',
#  'Hallertauer Blanc',
#  'Hallertauer Blanc (DE)',
#  'Hallertauer Hersbrucker',
#  'Hallertauer Mandarina',
#  'Hallertauer Mittelfrueh',
#  'Hallertauer Mittelfrüh',
#  'Hallertauer Mittelfrüh (DE)',
#  'Hallertauer Tradition (DE)',
#  'Hallertauer Tradition - Wet Hop',
#  'Hallertauer mittelfrueh',
#  'Hallertaur mittelfrueh',
#  'Hallerteau',
#  'Halletau',
#  'Harmonie',
#  'Harmony',
#  'Hedgy',
#  'Helga',
#  'Helga (AU)',
#  'Helga (DE)',
#  'Helga (US)',
#  'Hemlock Tips',
#  'Herald (UK)',
#  'Herkules (DE)',
#  'Hersbrucker',
#  'Hersbrucker (DE)',
#  'Hersbrucker HT',
#  'Hobart Street Zues',
#  'Home grown mixed hops',
#  'Home hop',
#  'Homegrown Cascade',
#  'Homegrown Cascade and Centennial, Chinook, Columbus, Willamette',
#  'Homegrown Cascade, Chinook, Centennial, Columbus, Willamette',
#  'Homegrown Cascade? (Front yard)',
#  'Homegrown Cenntinnuggette',
#  'Homegrown Fresh Mix',
#  'Homegrown Sterling',
#  'Homegrown Sterling? (Backyard)',
#  'Hop Combo',
#  'Hop Hash',
#  'Hop Jizz',
#  'Hop Oil',
#  'Hop Shot',
#  'Hop Shot Extract',
#  'Hop Steiner Exp 6300 (US)',
#  'Hop extract 5 ml',
#  'Hop hash',
#  'Hop shot extract',
#  'HopShot',
#  'HopShot (US)',
#  'HopShot 10ml',
#  'Hopbursted Blend',
#  'Hopbursted blend',
#  'Hopshot',
#  'Hopshot (US)',
#  'Hopshot (ml)',
#  'Hopshot Extract',
#  'Hopshots',
#  'Hopsteiner Bravo',
#  'Hopsteiner Bravo (US)',
#  'Hopsteiner Delta (US)',
#  'Horizon',
#  'Horizon (US)',
#  'Houblon des marais picards',
#  'Huel Melon',
#  'Huell',
#  'Huell  Melon',
#  'Huell Melon',
#  'Huell Melon  (US)',
#  'Huell Melon (GE)',
#  'Huell Melon (US)',
#  'Huell melon',
#  'Hull Mellon',
#  'Hull Melon',
#  'Hull melon',
#  'Huller Bitterer',
#  'Humulus lupulus Aureus',
#  'Hüll Melon',
#  'IBU Injections',
#  'Idaho #7',
#  'Idaho 007',
#  'Idaho 7',
#  'Idaho 7 (Hop Hash)',
#  'Idaho 7 Hop Hash',
#  'Idaho 7 hop hash',
#  'Idaho 7 w/hop bag',
#  'Idaho Gem',
#  'Idaho-7',
#  'Idaho7 New Crop',
#  'Iunga',
#  'Iunga (PL)',
#  'J-17',
#  'J17',
#  'Jarrlyo',
#  'JarryLo',
#  'Jarrylo',
#  'Jarrylo (US)',
#  'Jarrylo [Summit (US)]',
#  'Jaryllo',
#  'Jester',
#  'Joes (Maybe Fuggle)',
#  'Julian Gold',
#  'Julian Gold3',
#  "Julya and Fred's Homegrown",
#  'Junga',
#  'Kazbeck',
#  'Kazbeck (CZ)',
#  'Kazbek',
#  'Kazbek (CZ)',
#  'Keg Hop - Centennial',
#  'Keg Hop - Columbus',
#  'Keg Hop - Simcoe Leaf',
#  'Kent Golding',
#  'Kent Golding (UK)',
#  'Kent Golding (US)',
#  'Kent Goldings',
#  'Kirin',
#  'Kohatu',
#  'Kohatu (AU)',
#  'Kohatu (NZ)',
#  'Lambic Blend',
#  'Lambic Hop',
#  'Lambic Hop Blend',
#  'Latir (Neomexicanus)',
#  'Lavender Flower',
#  'Legacy',
#  'Legacy (US)',
#  'Lemon Balm',
#  'Lemon Drop',
#  'Lemon Verbena',
#  'Lemon Zest',
#  'Lemon drop',
#  'LemonDrop',
#  'Lemond Drop',
#  'Lemondrop',
#  'Lemondrop (US)',
#  'Lemondrop Experimental',
#  'Lemondrop experimental',
#  'Lexy Green C4',
#  'Liberty',
#  'Liberty (US)',
#  'Liberty (US) [PRIMARY]',
#  'Local',
#  'Lomic',
#  'Lomik',
#  'Lomik (PL)',
#  'Loral',
#  'Loral (HBC 291)',
#  'Loral Lupulin Powder',
#  'Lubelska',
#  'Lublin (Lubelski)',
#  'Lublin (PL)',
#  'LupuLN2 Simcoe Cryo Hops(US)',
#  'MANDARINA BAVARIA',
#  'MB (DE)',
#  'MI Copper',
#  'MOSAIC',
#  'Mackinac',
#  'Mackinac Wet',
#  'Madarina bavaria',
#  'Magic Hop Dust',
#  'Magnum',
#  'Magnum (DE)',
#  'Magnum (Pellet)',
#  'Magnum (US)',
#  'Magnum (US) (bittering top-up)',
#  'Magnum T90 (DE)',
#  'Magnum.',
#  'Mandarina',
#  'Mandarina (DE)',
#  'Mandarina (GE)',
#  'Mandarina Bavaira',
#  'Mandarina Bavara',
#  'Mandarina Bavaria',
#  'Mandarina Bavaria (DE)',
#  'Mandarina Bavaria(DE)',
#  'Mandarina Bravaria',
#  'Mandarina bavaria',
#  'Mandarine',
#  'Mandarinskall bavaria',
#  'Manderina Bav',
#  'Manderina Bavaria',
#  'Mapuche',
#  'Marco Polo',
#  'Maryinka',
#  'Marynka',
#  'Marynka (PL)',
#  'Mathon',
#  'Medusa',
#  'Medusa  (US)',
#  'Medusa (US)',
#  'Meeting Hops',
#  'Melon',
#  'Meridian',
#  'Meridian (US)',
#  'Merkur (DE)',
#  'Michigan Copper',
#  'Millenium (US)',
#  'Mintras',
#  'Mittelfrüh (DE)',
#  'Moasic',
#  'Montana',
#  'Moon Man Hop Blend',
#  'Mosaic',
#  'Mosaic  (US)',
#  'Mosaic (2014)',
#  'Mosaic (AU)',
#  'Mosaic (HBC 369)',
#  'Mosaic (HBC 369) CryoHop',
#  'Mosaic (HBC-369)',
#  'Mosaic (US)',
#  'Mosaic 4:00',
#  'Mosaic 4:30',
#  'Mosaic 4:45 (add whirlfloc)',
#  'Mosaic 4:50 (add YN) get honey ready',
#  'Mosaic 5:00',
#  'Mosaic Cryo (Lupulin, 26.00% AA)',
#  'Mosaic Cryohop',
#  'Mosaic HBC 369',
#  'Mosaic brand HBC 369 cv (US)',
#  'Mosaic/HBC 369 Experimental (Simcoe Sister Strain)',
#  'Mosaic®',
#  'Mosaic™',
#  'Mosaic™ (US)',
#  'Mosaic™ (US)     Dry Hop 1',
#  'Mosaic™ (US)     Dry Hop 2',
#  'Mosaic™ (US)     Dry Hop 3',
#  'Mosaic™ (US)     Keg Hop',
#  'Mosaic™ (US) (DH1)',
#  'Mosaic™ (US) (DH2)',
#  'Mosaic™ (US) (DH3)',
#  'Mosaic™ (US) (DH4)',
#  'Mosaic™ (US) (hop rocket 2)',
#  'Mosaic™ (US) (hop rocket)',
#  'Mosaic™ (US) DH 1',
#  'Mosaic™ (US) DH 2',
#  'Mosaic™ (US) DH1',
#  'Mosaic™ (US) DH2',
#  'Mosaic™ (US) Hop Rocket',
#  'Mosaic™ (US) Keg',
#  'Mosaic™ (US) Keg Hop',
#  'Mosaic™ (US) Lupulin',
#  'Mosaic™ (US) Whirlpool',
#  'Mosaic™ (US) [PRIMARY]',
#  'Mosaic™ (US) [SECONDARY]',
#  'Mosaic™ (US) hop rocket',
#  'Mosaic™ (US) in 2o',
#  'Mosaic™ Cryo (US)',
#  'Mosiac',
#  'Mosiac (US)',
#  'Mosiac™',
#  'Motueka',
#  'Motueka (NZ)',
#  'Motueka/Helga/Vic Secret',
#  'Mount Hood',
#  'Mount Hood (US)',
#  'Mount Hood (US) homegrown',
#  'Mount Rainier (US)',
#  'Moutere',
#  'Moutere (NZ)',
#  'MrBeerWCPA HME',
#  'Mt. Hood',
#  'Multihead',
#  'Mystery X (US)',
#  'Mystery X (US) - Wet Hop',
#  'Mystery hop mix',
#  'N brewer',
#  'N1/69',
#  'NB Furious Dry Hop Blend',
#  'NELSON SAVIN',
#  'NY State Chinook (US)',
#  'NZ Cascade',
#  'NZ Dr Rudi',
#  'NZ Fuggle',
#  'NZ Fuggle (NZ)',
#  'NZ Fuggles (NZ)',
#  'NZ Green Bullet (NZ)',
#  'NZ Nelson Sauvin',
#  'NZ Super Alpha',
#  'Nelson',
#  'Nelson Sauvignon',
#  'Nelson Sauvin',
#  'Nelson Sauvin (NZ)',
#  'Nelson Sauvin (NZ) (DH1)',
#  'Nelson Sauvin (NZ) (DH2)',
#  'Nelson Sauvin (NZ) (hop rocket 2)',
#  'Nelson Sauvin (NZ) (hop rocket)',
#  'Nelson Sauvin (NZ) DH1',
#  'Nelson Sauvin (NZ) DH2',
#  'Nelson sauvin',
#  'Nettle',
#  'New Zealand Cascade',
#  'New Zealand Fuggle',
#  'New Zealand Green Bullet (NZ)',
#  'New Zealand Hallertau',
#  'New Zealand Pacific Hallertau',
#  'New Zealand Pacific Jade',
#  'New Zealand Super Alpha',
#  'New Zealand Super High Alpha Hop',
#  'Newport',
#  'Newport (US)',
#  'Northdown',
#  'Northdown (UK)',
#  'Norther Brewer',
#  'Northern Advance',
#  'Northern Brewer',
#  'Northern Brewer (DE)',
#  'Northern Brewer (UK)',
#  'Northern Brewer (US)',
#  'Nuget Argentino',
#  'Nugget',
#  'Nugget (DE)',
#  'Nugget (Local Leaf)',
#  'Nugget (US)',
#  'Nuggetzilla',
#  'Old Cali Hop',
#  'Olicana',
#  'Olympic (US)',
#  'Omega',
#  'Opal',
#  'Opal (DE)',
#  'Orbit (NZ)',
#  'Organic Cascade',
#  'Organic Fuggle',
#  'Organic Liberty',
#  'Organic Perle',
#  'Other',
#  'Otto Supreme',
#  'Pacific Gem (NZ)',
#  'Pacific Hallertau (NZ)',
#  'Pacific Jade',
#  'Pacific Jade (NZ)',
#  'Pacific Jade Extract (NZ)',
#  'Pacific jade',
#  'Pacifica (NZ)',
#  'Palisade (US)',
#  'Palisade Cryo',
#  'Pekko',
#  'Pekko (US)',
#  'Perle',
#  'Perle (DE)',
#  'Perle (US)',
#  'Phoenix (UK)',
#  'Phoenix (UK) (wet 215gram)',
#  'Pilgrim',
#  'Pilgrim (UK)',
#  'Pine Fruit',
#  'Pine Fruit/Apollo',
#  'Pinefruit EXP',
#  'Pioneer (UK)',
#  'Polaris',
#  'Polaris (DE)',
#  'Polish Lublin',
#  'Polish Lublin (PL)',
#  'Polish Marynka (PL)',
#  'Premiant',
#  'Premiant (CZ)',
#  'Premiant (Saaz)',
#  'Pride of Ridgewood',
#  'Pride of Ringwood (AU)',
#  'Progress',
#  'Progress (UK)',
#  'Qingdao Flower',
#  'Rakau',
#  'Rakau (AU)',
#  'Rakau (NZ)',
#  'Record',
#  'Relax',
#  'Revolution',
#  'Riwaka (NZ)',
#  'Roadhouse (unknown)',
#  'Rogue Farms Idependent hops',
#  'Ron Mexico HBC 438',
#  'Rudi',
#  'S Aroma',
#  'S PASSION',
#  'S Pass',
#  'S. Aroma',
#  'SAB 98J1763',
#  'SAB Blend',
#  'SAB Pale',
#  'SAB XJA/436',
#  'SEREBRIANKA',
#  'SIMCOE',
#  'Saaz',
#  'Saaz (CH)',
#  'Saaz (CSF)',
#  'Saaz (CZ)',
#  'Saaz (China)',
#  'Saaz (Czech Republic)',
#  'Saaz (US)',
#  'Saaz (Xinjiang)',
#  'Saaz (Żatecki)',
#  'Saaz 2017',
#  'Saaz Hop Oil (added at bottling) (US)',
#  'Saaz hop oils (US)',
#  'Saazer',
#  'Sab18',
#  'Santiam (US)',
#  'Saphir (DE)',
#  'Saphir (German Organic)',
#  'Sauvin, New Zealand',
#  'Savinjsky',
#  'Sazz 2017',
#  'Scottish Gruit',
#  'Select Spalt',
#  'Serebrianka',
#  "Seven C's",
#  "Seven C's (US)",
#  'Shinshuwase',
#  'Simcoe',
#  'Simcoe (US)',
#  'Simcoe (US) (late)',
#  'Simcoe (US) or Azaaca (US)',
#  'Simcoe Cryo',
#  'Simcoe CryoHop',
#  'Simcoe Lupulin Powder',
#  'Simicoe',
#  'Sirachi Ace',
#  'Sirius',
#  'Sladek',
#  'Sladek (CZ)',
#  'Sladek (Saaz)',
#  'Slovenian Bobek',
#  'Slovenian Bobek (SI)',
#  'Slow Ride Blend',
#  'Sládek',
#  'Smallest HopYard blend',
#  'Smaragd',
#  'Smaragd (DE)',
#  'Smooth Cone',
#  'Smoothcone',
#  'Smoothcone? (ZEH Fence Hop NZ)',
#  'Sonnet',
#  'Sonnet Golding',
#  'Sonnet Golding (US)',
#  'Sonnet Goldings',
#  'Sorachi Ace',
#  'Sorachi Ace (2013)',
#  'Sorachi Ace (JP)',
#  'Southern Aroma',
#  'Southern Cross',
#  'Southern Cross (NZ)',
#  'Southern Cross (NZ) DH 2',
#  'Southern Cross (NZ) DH1',
#  'Southern Dawn',
#  'Southern Passion',
#  'Southern Passion (US4/78)',
#  'Southern Promise',
#  'Southern Star',
#  'SouthernStar',
#  'Sovereign',
#  ...]

# %% [markdown]
# ---
# ## Converting Weights of Fermentables and Hops
#
# First, I need to write a function to convert each of the different units for weight that exist in the data set to a singular unit. For fermentables, I'll use pounds, and for hops I'll use ounces.

# %%
def convert_to_pounds(amount, unit):
    if unit == 'lb':
        return amount
    if unit == 'oz':
        return round(amount/16, 3)
    if unit == 'g':
        return round(amount * 0.00220462, 3)
    if unit == 'kg':
        return round(amount * 2.20462, 3)
    
def convert_to_oz(amount, unit):
    if unit == 'oz':
        return amount
    if unit == 'lb':
        return amount*16
    if unit == 'g':
        return round(amount*0.035274, 3)

# %%
styles = pd.read_csv('../Data/styleData.csv')
recipes = pd.read_csv('../Data/recipeData.csv')

# %%
styles.head()
# Out:
#                     Style  StyleID
# 0                 Altbier        1
# 1  Alternative Grain Beer        2
# 2  Alternative Sugar Beer        3
# 3      American Amber Ale        4
# 4     American Barleywine        5

# %%
styles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 2 columns):
# Style      175 non-null object
# StyleID    176 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.8+ KB

# %%
styles.isnull().sum()
# Out:
# Style      1
# StyleID    0
# dtype: int64

# %%
styles['Style'].sort_values()
# Out:
# 0                             Altbier
# 1              Alternative Grain Beer
# 2              Alternative Sugar Beer
# 3                  American Amber Ale
# 4                 American Barleywine
# 5                  American Brown Ale
# 6                        American IPA
# 7                      American Lager
# 8                American Light Lager
# 9                   American Pale Ale
# 10                    American Porter
# 11                     American Stout
# 12                American Strong Ale
# 13                American Wheat Beer
# 14         American Wheat or Rye Beer
# 15                         Apple Wine
# 16           Australian Sparkling Ale
# 17               Autumn Seasonal Beer
# 18                      Baltic Porter
# 19                  Belgian Blond Ale
# 20            Belgian Dark Strong Ale
# 21                     Belgian Dubbel
# 22          Belgian Golden Strong Ale
# 23                   Belgian Pale Ale
# 24              Belgian Specialty Ale
# 25                     Belgian Tripel
# 26                    Berliner Weisse
# 27                        Best Bitter
# 28                     Bière de Garde
# 29                         Blonde Ale
#                     ...
# 147          Specialty IPA: Black IPA
# 148          Specialty IPA: Brown IPA
# 149            Specialty IPA: Red IPA
# 150            Specialty IPA: Rye IPA
# 151          Specialty IPA: White IPA
# 152             Specialty Smoked Beer
# 153          Specialty Wood-Aged Beer
# 154    Spice  Herb  or Vegetable Beer
# 155           Standard American Lager
# 156          Standard/Ordinary Bitter
# 157       Straight (Unblended) Lambic
# 158                     Strong Bitter
# 159                 Strong Scotch Ale
# 160                        Sweet Mead
# 161                       Sweet Stout
# 162                  Traditional Bock
# 163                 Traditional Perry
# 164                   Trappist Single
# 165                    Tropical Stout
# 166                      Vienna Lager
# 167                         Wee Heavy
# 168                         Weissbier
# 169                  Weizen/Weissbier
# 170                        Weizenbock
# 171                         Wheatwine
# 172               Wild Specialty Beer
# 173              Winter Seasonal Beer
# 174                           Witbier
# 175                    Wood-Aged Beer
# 110                               NaN
# Name: Style, Length: 176, dtype: object

# %%
styles.loc[108:112, :]
# Out:
#                       Style  StyleID
# 108           Munich Helles      109
# 109       New England Cider      110
# 110                     NaN      111
# 111    North German Altbier      112
# 112  Northern English Brown      113

# %%
recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65499 entries, 0 to 65498
# Data columns (total 23 columns):
# BeerID           65499 non-null int64
# Name             65498 non-null object
# URL              65499 non-null object
# Style            64958 non-null object
# StyleID          65499 non-null int64
# Size(L)          65499 non-null float64
# OG               65499 non-null float64
# FG               65499 non-null float64
# ABV              65499 non-null float64
# IBU              65499 non-null float64
# Color            65499 non-null float64
# BoilSize         65499 non-null float64
# BoilTime         65499 non-null int64
# BoilGravity      62512 non-null float64
# Efficiency       65499 non-null float64
# MashThickness    38651 non-null float64
# SugarScale       65499 non-null object
# BrewMethod       65499 non-null object
# PitchRate        30904 non-null float64
# PrimaryTemp      45753 non-null float64
# PrimingMethod    6191 non-null object
# PrimingAmount    4387 non-null object
# UserId           21113 non-null float64
# dtypes: float64(13), int64(3), object(7)
# memory usage: 11.5+ MB

# %%
recipes.isnull().sum()
# Out:
# BeerID               0
# Name                 1
# URL                  0
# Style              541
# StyleID              0
# Size(L)              0
# OG                   0
# FG                   0
# ABV                  0
# IBU                  0
# Color                0
# BoilSize             0
# BoilTime             0
# BoilGravity       2987
# Efficiency           0
# MashThickness    26848
# SugarScale           0
# BrewMethod           0
# PitchRate        34595
# PrimaryTemp      19746
# PrimingMethod    59308
# PrimingAmount    61112
# UserId           44386
# dtype: int64

# %%
beer_advocate = pd.read_csv('../Data/beer_reviews.csv')

# %%
beer_advocate.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv  beer_beerid
# 0            Sausa Weizen       5.0        47986
# 1                Red Moon       6.2        48213
# 2  Black Horse Black Beer       6.5        48215
# 3              Sausa Pils       5.0        47969
# 4           Cauldron DIPA       7.7        64883

# %%
beer_advocate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 13 columns):
# brewery_id            1586614 non-null int64
# brewery_name          1586599 non-null object
# review_time           1586614 non-null int64
# review_overall        1586614 non-null float64
# review_aroma          1586614 non-null float64
# review_appearance     1586614 non-null float64
# review_profilename    1586266 non-null object
# beer_style            1586614 non-null object
# review_palate         1586614 non-null float64
# review_taste          1586614 non-null float64
# beer_name             1586614 non-null object
# beer_abv              1518829 non-null float64
# beer_beerid           1586614 non-null int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 157.4+ MB

# %%
beer_advocate.isnull().sum()
# Out:
# brewery_id                0
# brewery_name             15
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# review_profilename      348
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_abv              67785
# beer_beerid               0
# dtype: int64

# %%
67785/beer_advocate.shape[0]
# Out:
# 0.042723056773733246

# %%
len(beer_advocate[beer_advocate['beer_abv'].isnull()]['beer_beerid'].unique())
# Out:
# 17043

# %%
overlap_names = set(beer_advocate[beer_advocate['beer_abv'].isnull()]['beer_name'].unique()).intersection(set(beer_advocate[beer_advocate['beer_abv'].notnull()]['beer_name'].unique()))

# %%
overlap_names
# Out:
# {'Apricot Ale',
#  'Maple Brown Ale',
#  'Irish Red Ale',
#  'Dry Stout',
#  'Wassail Ale',
#  'Citra',
#  'Milk Chocolate Stout',
#  'Black',
#  'Groovy Brew',
#  'Celtic Cream Ale',
#  'Copper Ale',
#  'Cayucos Beach Ale',
#  'Cherry Lager',
#  'Smoked Bock',
#  'Gold Rush Lager',
#  'Imperial Hefeweizen',
#  'New Zealand Pilsner',
#  'Freedom Stout',
#  'Double IPA',
#  'Rye Porter',
#  'Palisades Pale Ale',
#  'Dubbel Trouble',
#  'Marketing Ploy',
#  'Zhigulovskoye',
#  'Happy Pils',
#  'Stonehenge',
#  'Doppelbock',
#  'Honey Beer',
#  'E.S.B.',
#  'Midtown Brown',
#  'Special Belgian Ale',
#  'Peach Wheat',
#  'Red Baron',
#  'Chipotle Porter',
#  'Farmhouse Ale',
#  'Smokehouse Porter',
#  'Resinous Rye',
#  'Simcoe Pale Ale',
#  'Centennial',
#  'Pilsner',
#  'Alt Bier',
#  'Belgian Blonde Ale',
#  'Zlatorog',
#  'Honey Lager',
#  'Juniper Rye',
#  'Victory ESB',
#  'Pullman Porter',
#  '11.0',
#  'Stallion Stout',
#  'Zephyr',
#  'Firehouse Red',
#  'Humboldt Brown Hemp Ale',
#  'Honey Raspberry Ale',
#  'Maibock',
#  'Black Rock Stout',
#  'Chocolate Ale',
#  'Tenth Anniversary Ale',
#  'Dunkel Weiss',
#  'Christmas Ale 2004',
#  'London Porter',
#  "Lanigan's Irish Ale",
#  'Raspberry Stout',
#  'Amber Lager',
#  'Plan B IPA',
#  'Black IPA',
#  'Premium Lager',
#  'Bavarian Style Hefeweizen',
#  'Alter Ego Altbier',
#  'Whitetail Wheat',
#  'Hoppy Holidaze',
#  'Yellow Snow IPA',
#  'Winterbock',
#  'Black Forest Imperial Stout',
#  'Graduation Ale',
#  'Christmas Ale 2007',
#  'Navidad',
#  'Northern Light Lager',
#  'Ginja',
#  'Dusseldorf Alt',
#  "McGuire's India Pale Ale",
#  'Cherry Cream Stout',
#  'Black Jack',
#  'Riverside Red',
#  'Road Kill Barleywine Style Ale',
#  'American Stout',
#  'Maximilian',
#  'Frog Island Amber Ale',
#  'Rock Hard Red',
#  'Karma Citra',
#  'Hemp Ale',
#  'Winter Porter',
#  'Blonde Ale',
#  'Gose',
#  'Piedmont Porter',
#  "Nigel's ESB",
#  'Honey Blond',
#  'Iron Horse Stout',
#  'Amarillo IPA',
#  'Autumnfest',
#  'Chocolate Bock',
#  'Harvest Moon',
#  'Raspberry Weiss',
#  'Columbus Pale Ale',
#  'Fresh Hop',
#  'Four Grain Stout',
#  'Black Eye',
#  'Harvest Wheat Ale',
#  'Pilsenskoye',
#  'Barefoot Wit',
#  'La Belle Province',
#  'Williamsburg Pale Ale',
#  'Plain Porter',
#  'Great Pumpkin Ale',
#  'Snake River IPA',
#  'Bourbon Barrel Aged Winter Warmer',
#  'Mocha Java Stout',
#  'Powerhouse Pale Ale',
#  'West Side Wheat',
#  'Dortmunder',
#  'Cinnamon Girl',
#  'Summer IPA',
#  'Cherry Lambic',
#  'Belgian Style Golden Ale',
#  'Pintail Pale Ale',
#  'Old Man Ale',
#  'Extra Special Bitter',
#  'Juniper Pale Ale',
#  'Oktoberfest Bier',
#  'Kismet',
#  'Chaos',
#  'Hammerhead Red',
#  'Helles Bock',
#  'Blueberry Lager',
#  'Bombay Bomber IPA',
#  'Alewife Ale',
#  'Flanders Red',
#  'Miami Weiss',
#  'Vienna Lager',
#  'Panic Attack',
#  'New World Porter',
#  'Mary Hoppins',
#  'Cherry Brown Ale',
#  'Summer Solstice',
#  'Xtra Pale Ale',
#  'May Bock',
#  'Black Ale',
#  'Oktoberfest',
#  'Belgian Sour',
#  'Cherry Wheat',
#  'Carolina Blonde',
#  'Jackpot Porter',
#  'Honey Blonde',
#  'Buckeye Brown',
#  'Blueberry Wheat Ale',
#  'Fire Chief Ale',
#  'Equinox',
#  'Brown Ale',
#  'Vanilla Cream Stout',
#  'Summer Wit',
#  'Albino Rhino Ale',
#  'Punkinator',
#  'Red, Wheat, And Blue',
#  'Pioneer Lager',
#  'Amber Bock',
#  'Zwickelbier',
#  'White Out Winter Ale',
#  'Belgian-Style Abbey Ale',
#  'Stout',
#  'Blueberry Belch',
#  'Wooden Shoe Bock',
#  'Big Horn Bitter',
#  'Black Diamond Imperial Porter',
#  'English Mild',
#  'Coal Porter',
#  'Sweet Magnolia Brown',
#  'Copperhead',
#  'Kellerbier',
#  'Keller Pils',
#  'Oktoberfest Lager',
#  'Drunkin Pumpkin',
#  'Railhouse IPA',
#  'Hoppy Porter',
#  'Golden Export',
#  'Chocolate Rye Porter',
#  'Magnum Pale Ale',
#  'Latitude',
#  'Mocha Porter',
#  'Traditional Lager',
#  'Maple Smoked Porter',
#  'XPA',
#  'Starry Night Stout',
#  'Novemberfest',
#  'Robusto Porter',
#  'Glacier IPA',
#  'Uberhoppy IPA',
#  'Barrel Aged Wee Heavy',
#  "Farmer's Tan",
#  'Christmas Cheer',
#  'Hefe Weiss',
#  'Imperial Pale Ale',
#  'Dortmunder Export',
#  'Purple Haze',
#  'Prime Time',
#  'Perseus Porter',
#  'Good Hope IPA',
#  'Blackberry Wheat',
#  'Wizard Wheat',
#  'Altbairisch Dunkel',
#  'Summer Bock',
#  "Ichabod's Pumpkin Ale",
#  'Hefeweizen',
#  'Twisted Sister',
#  'Red Eye Rye',
#  'Belgian Witbier',
#  'Heart Of Darkness',
#  'Bronze Ale',
#  'Dunkel Weisse',
#  'Scottish Style Ale',
#  'Summer Wheat',
#  'India Pale Ale',
#  'Wet Dog',
#  'Double Chocolate Stout',
#  'Hop Grenade',
#  'Dry Irish Stout',
#  'Alternator',
#  'Berliner Weiss',
#  'Scotch Ale',
#  'Midnight Porter',
#  'Dear Abbey Dubbel',
#  "Lion's Pride",
#  'Homewrecker',
#  'Abbey',
#  'Special Pale Ale',
#  'Black Forest Lager',
#  'Sesquicentennial Ale',
#  'Dunkles',
#  'Blitzen IPA',
#  'Fire Engine Red',
#  'Bavarian Weizen',
#  'Pale Rider',
#  'Black Forest',
#  'Harvest',
#  'Whitewater Wheat',
#  'DunkelWeizen',
#  'Palatine Porter',
#  'Mild Ale',
#  'Porter Fume',
#  'Framboise',
#  'Hell',
#  'Ex-Wife Extra Bitter',
#  'Smoked Porter',
#  'Southend Blonde',
#  'Special Bitter',
#  'Imperial Oatmeal Stout',
#  'Honey Oatmeal Stout',
#  'Berserker',
#  'Black Hops',
#  'Double Bock',
#  'Summerfest',
#  'Hop Candy',
#  'Wit Bier',
#  'Sticky Fingers',
#  'Amber Weizen',
#  'Double Pale Ale',
#  'Strawberry',
#  'Celis Grand Cru',
#  'British Bitter',
#  'Coconut Stout',
#  'Vanilla Bourbon Stout',
#  'Bourbon Porter',
#  'Belgian IPA',
#  'Weizenheimer',
#  'Oatmeal Stout',
#  '15th Anniversary Ale',
#  'Raspberry Blonde',
#  'Vienna-Style Lager',
#  'Imperial India Pale Ale',
#  'Black Forest Porter',
#  'Hip Hop',
#  'Ghost Town Pumpkin Ale',
#  'Vienna Style Lager',
#  '10.0',
#  'ReplicAle',
#  'American Ale',
#  "Lasto's Oatmeal Stout",
#  'California Common',
#  'Weizenbock',
#  'Bourbon Barrel Aged Wee Heavy',
#  'Espresso Stout',
#  'Brown Eyed Girl',
#  'Main Street Wheat',
#  'Pub Ale',
#  'Old Woody',
#  'Maple Stout',
#  'Bavarian Weiss',
#  'Fevre River Ale',
#  'Bourbon Barrel Brown',
#  'Pumpkin',
#  'Smelt Camp Strong Ale',
#  'Cream Ale',
#  'Strawberry Wheat',
#  'Spring Fever',
#  'Lookout Stout',
#  'Honey Wheat',
#  'Christmas Ale 2008',
#  'Black Jack Stout',
#  'Alembic Pale Ale',
#  "Rosemary's Baby",
#  'Hazelnut Porter',
#  'Red River Ale',
#  'El Jefe',
#  'Belgium Wit',
#  'Rauchbock',
#  'Coffee Porter',
#  '14th Anniversary Ale',
#  'Heather',
#  'La Brune',
#  'Beach Blonde',
#  'Bière De Noel',
#  'Honey Porter',
#  'Kolsch Ale',
#  'Sunset Red Ale',
#  'Raspberry Weizen',
#  "Ploughman's Ale",
#  'Brooklyn Smoked Porter',
#  'Christmas Ale 2009',
#  'Cole Porter',
#  'Belgian Brown Ale',
#  'Kriek',
#  'Classic Pilsner',
#  'C.P.A.',
#  'Smoked Rye',
#  'Dirty Blonde',
#  'Peach Lambic',
#  'Brown Stout',
#  'Inspiration Ale',
#  'Lighthouse Lager',
#  'Gothic Ale',
#  'Black Rabbit Porter',
#  'German Chocolate Stout',
#  'Magnum IPA',
#  'IPA',
#  'Anthracite Ale',
#  'For Richer Or Porter',
#  'Bavarian Pilsener',
#  'Honey Pale Ale',
#  'Highlander Scotch Ale',
#  'Dark Rye',
#  '80 Shilling',
#  'Irish Amber',
#  'Frambozen Raspberry Brown Ale',
#  'Sour Puss',
#  'Hopscotch',
#  'Sunshine',
#  'Imperium',
#  'Presque Isle Pilsner',
#  'Belgian Saison',
#  'Northwest Red Ale',
#  'House Brand IPA',
#  'House IPA',
#  'Summer Beer',
#  'Huckleberry Ale',
#  'Brown',
#  'Yippee IPA',
#  "BJ's Brewhouse Blonde",
#  'Entire Porter',
#  'Hop Common',
#  'Double Vision',
#  'Dark Saison',
#  'Rye',
#  'Big Red Ale',
#  'Copper Moon',
#  'Nut Brown',
#  'Witbier',
#  'Orange Blossom',
#  'Ironwood Dark',
#  'Scarecrow ESB',
#  'Barleywine',
#  'Christmas Ale 2005',
#  'Crystal',
#  'Park Pirminator',
#  '11th Anniversary Double IPA',
#  'Lambic',
#  'Sweet Stout',
#  'Irish Stout',
#  'Atomic Pale Ale',
#  'Belgian Gold',
#  'Raspberry Lambic',
#  'Light',
#  'Prairie Pale Ale',
#  'Chiara',
#  'Black Watch Scotch Ale',
#  'American Red Ale',
#  'Bavarian Wheat',
#  'Dunkelweiss',
#  'Celtic Stout',
#  'Black Forest Altbier',
#  'Eclipse Black IPA',
#  "Brewer's Gold",
#  'Southern Brown Ale',
#  'Strong Ale',
#  'Summer Ale',
#  'Strawberry Blonde Ale',
#  "McGuire's Light Ale",
#  'Festivus Ale',
#  'Dry Hopped IPA',
#  'Goldie Hops',
#  'Bourbon Stout',
#  'Belgian White Ale',
#  'XXX-Mas Ale',
#  'The Big O',
#  'Fresh Hop Ale',
#  'Dark Ale',
#  "Paddler's Pale Ale",
#  'Pumpkin Ale',
#  'Blue Collar Brown',
#  'Bourbon Barrel Aged Stout',
#  'Schwarzbier',
#  'Old Elk Brown Ale',
#  'Cascade IPA',
#  'Maple Cream Ale',
#  'Smoke Out',
#  'Rauch',
#  'Summer Brew',
#  'Pumpkinfest',
#  'Rattlesnake IPA',
#  'Chocolate Stout',
#  'Mesa Pale Ale',
#  'German Pilsener',
#  'Pro-Am Porter',
#  "Farmer's Daughter",
#  'Ambrosia',
#  'Golden Spike Ale',
#  'Pro-Am',
#  'Stock Ale',
#  'Triple Play',
#  'Straight Pipe Stout',
#  'No Name IPA',
#  'Ryedentity Crisis',
#  'Pumkin Ale',
#  'Cross Eyed Rye',
#  'Hop Head Red',
#  'Desert Dawn',
#  'Imperial Stout',
#  'Old Town Nut Brown Ale',
#  'Rosebud',
#  'Ginger Brown',
#  'Steamboat Stout',
#  'Bah Humbug',
#  'Keller Kolsch',
#  'English Dark Mild',
#  'Whiskey Stout',
#  'Juleøl',
#  'Pub Draught Ale',
#  'Belgian Triple',
#  'Pier Pale Ale',
#  'Unity Brew',
#  'Premium',
#  'Chocolate Milk Stout',
#  'Batch 1000',
#  'Golden Wheat Ale',
#  'Fresh Hop IPA',
#  'Centennial Ale',
#  'English Porter',
#  'Raven Stout',
#  'Belgian-Style Tripel',
#  'Fat Boy Porter',
#  "S'no Angel",
#  'Illuminator',
#  'Raspberry Hefeweizen',
#  'Nugget IPA',
#  'Total Disorder Porter',
#  'Haystack Hefeweizen',
#  'Red Velvet',
#  'Euphoria',
#  'Session Pale Ale',
#  'Honey Lager Light',
#  'Bombay IPA',
#  'Bull Run Bitter',
#  'Walnut Brown Ale',
#  '21st Amendment',
#  'Blackbird Porter',
#  'Simcoe IPA',
#  'Cask Conditioned IPA',
#  'Endless Summer',
#  'Barrel Aged Scotch Ale',
#  'Menage A Trois',
#  'I.P.A',
#  'Vienna Gold',
#  'Winter Spice',
#  'Irish Dry Stout',
#  'Chocolate Orange Stout',
#  'Old Ale',
#  "Barley's Alexander's Russian Imperial Stout",
#  'Golden Pride',
#  'Prairie Porter',
#  'Rye PA',
#  'American Amber Lager',
#  '2nd Anniversary',
#  'Hop Monster',
#  'Imperial Red Ale',
#  'Vanilla Cream Porter',
#  'Industrial Porter',
#  'Milk Stout',
#  'Belgian Brown',
#  'Porter',
#  'The One',
#  'Honey Cream Ale',
#  "Buffalo Tooth's Old Ale",
#  'Jeremiah Red',
#  'Pumpkinhead Ale',
#  'Chocolate Thunder Porter',
#  'Baltic Porter',
#  'Giddyup Stout',
#  'Ten',
#  'Gueze',
#  'American Pale Ale',
#  'Belgian White',
#  'Runabout Red Ale',
#  'Envy',
#  'Charlie Brown',
#  'Cherry Saison',
#  'Buttface Amber Ale',
#  'Chocolate Porter',
#  'Pumpkin Spice Ale',
#  'Sweet Georgia Brown',
#  'Apple Pie',
#  'Antler Ale',
#  'Schwartz',
#  'Red Bock',
#  'Windmill Wheat',
#  'Winter Wonder',
#  'Viking IPA',
#  'Mt. Whitney Pale Ale',
#  'Badlands Pale Ale',
#  'Hopnotic',
#  'Bitter Cold',
#  'Pub Light',
#  'British Mild Ale',
#  'Mexican Lager',
#  'Raging Rhino Red',
#  'Kvas',
#  'Vanilla Bean Porter',
#  'Quinte55ence',
#  'Red Sock Bock',
#  'Belgian Blonde',
#  'Raspberry Trail Ale',
#  'Maple Porter',
#  'White Ale',
#  'Harvest Wheat',
#  'Martovskoye',
#  'Apple Lambic',
#  'Amber Waves Ale',
#  'Heartland Wheat',
#  'Yankee Clipper IPA',
#  'Maifest',
#  'Smoked Lager',
#  'Dubbel Trubbel',
#  'Wet Hopped IPA',
#  'Export Stout',
#  'Belgian Wheat',
#  'Sunset Red',
#  'Bow Valley Brown Ale',
#  'Gold',
#  'Belgian Tripel',
#  'Hop Soup',
#  'Helles',
#  'Czech Pilsner',
#  "Rocket's Red Ale",
#  'Hefe Weizen',
#  'Hopinator',
#  'Blanche',
#  'Wheat IPA',
#  'Golden Apricot Ale',
#  'Blond',
#  'German Dunkel',
#  'Session Ale',
#  'Willamette Pale Ale',
#  'Frambozenbier',
#  "Barley's Centennial India Pale Ale",
#  'Wheatwine',
#  'Wheat Ale',
#  'Belgian Style Dubbel',
#  'Endless Summer Ale',
#  'Pub Draught',
#  'Spring Ale',
#  'James Brown Ale',
#  'Sleepy Hollow Nut Brown',
#  'Chili Beer',
#  'Honey Amber Ale',
#  'Rocktoberfest',
#  'Barley Legal',
#  'Winter Stout',
#  'Pilsen',
#  '483 Pale Ale',
#  'Imperial Brown Ale',
#  'Negra',
#  'Weiss',
#  'Extra Stout',
#  'Mai Bock',
#  'Summer Blonde',
#  'Cherry Stout',
#  'Seasonal Ale',
#  '20th Anniversary Ale',
#  'Tropic Thunder',
#  'Baja Blonde',
#  'DPA',
#  'Sleeping Giant IPA',
#  'Strong Brown Ale',
#  'Springboard',
#  'Oatmeal Brown',
#  'Prohibition Porter',
#  'Oyster Stout',
#  'Real Ale',
#  'Laurel IPA',
#  'Sunsplash Golden Ale',
#  'Pale Bock',
#  'Cherry Ale',
#  'Kringle',
#  'Black Magic Stout',
#  "Barley's Droughtfire IPA",
#  'Raspberry Rye',
#  'Shipwreck Stout',
#  'Winter White',
#  'Cherry Kriek',
#  'Rat Beach Red Ale',
#  'Kiltlifter Scotch Ale',
#  'German Pilsner',
#  "Santa's Little Helper",
#  'Hop Harvest',
#  'Victory Lager',
#  'Blueberry Blonde',
#  'Golden Eagle Ale',
#  'Hefe-Weizen',
#  'Dunkel',
#  'Weisse',
#  'Centennial Pale Ale',
#  'Beachwood BBQ 5th Anniversary Beer',
#  'Oatmeal Pale Ale',
#  'Dunkelweisse',
#  'Seaside Stout',
#  'Belgian Pale',
#  'Three Sheets',
#  'Elevator Imperial IPA',
#  'Wooden Shoe Stallostown Wheat',
#  'Schooner Porter',
#  'Liberator',
#  'Imperial Pilsner',
#  'Belgian Style',
#  'East Bay IPA',
#  'Hairy Weasel Hefeweizen',
#  'Shamrock Stout',
#  'Brown Bomber',
#  'Regal Lager',
#  'La Blonde',
#  'Winter Lager',
#  'Black Rock Porter',
#  'Oat Malt Stout',
#  'Black Magic',
#  'Smoked Hefeweizen',
#  'Copper Bock',
#  'Imperial Porter',
#  'Holiday Ale',
#  'Brun',
#  'Cornucopia',
#  'Maibock Lager',
#  'Winter Beer',
#  'Son Of A Peach',
#  'Bourbon Barrel Aged Imperial Stout',
#  'Bock',
#  'Dunkle',
#  'Sol',
#  'El Diablo',
#  'Blackout Stout',
#  'Wrecking Ball Rye',
#  'Warrior IPA',
#  'Munich Lager',
#  'Watermelon Wheat',
#  'Winter',
#  'Happy Ending',
#  'Dopplebock',
#  'Pacific Pale Ale',
#  'Bière De Mars',
#  'Fall Bock',
#  'Christmas Porter',
#  'Justice',
#  'Bison Blonde',
#  'Star Spangled Ale',
#  'Black Lager',
#  'Roggenbock',
#  'Blonde Lager',
#  'Hopfest',
#  'Resurrection',
#  'Amber Ale',
#  'White Tail Pale Ale',
#  'Rye Ale',
#  'Nettle Beer',
#  'Tavern Ale',
#  'Wildfire',
#  'Arroyo Amber Ale',
#  'Happy Pilsner',
#  'Nut Brown Ale',
#  'Raspberry Porter',
#  'Debilitator',
#  'Belgian Strong Ale',
#  'Uncle Fester',
#  'Hommel Bier',
#  'Black & Tan',
#  'North Star Amber',
#  'Singletrack Copper Ale',
#  'Ruby Ale',
#  'Session Mild',
#  'Mahogany',
#  'Farmhouse Saison',
#  'Rembrandt',
#  'Black Stallion Oatmeal Stout',
#  'Hot Blonde',
#  'Cocoa Porter',
#  'Rathskeller Amber Ale',
#  'Winterfest',
#  'Black Cat Porter',
#  'Honey Wheat Ale',
#  'Apricot Cream Ale',
#  'Rufus',
#  'Hoptoberfest',
#  'Nit Wit',
#  'Bourbon Barrel Aged Porter',
#  'Three Threads Porter',
#  'Clearwater Light',
#  'Trippel',
#  'Redbird Ale',
#  'Palisades IPA',
#  'Snakebite',
#  'Chocolate Raspberry Stout',
#  'Catherine The Great',
#  'Double Black IPA',
#  'Wee Heavy',
#  'Tyemnoye',
#  'Buttface Amber',
#  'Fire And Ice',
#  'Orange Honey Wheat',
#  'Summer',
#  'West Coast IPA',
#  'Red Lady Ale',
#  '5th Anniversary Ale',
#  'Summertime Ale',
#  'Dark Humor',
#  'Russian Imperial Stout',
#  'Kristalweizen',
#  'Sunset Summer Ale',
#  'Tatonka Stout',
#  'Purgatory Pale Ale',
#  'Black Knight',
#  "McGuire's Porter",
#  'Roggen Rye',
#  'Frambozen',
#  'Robust Porter',
#  'Tripel',
#  'Sparhawk Golden Ale',
#  'Washington Wheat',
#  'Brune',
#  'Java Stout',
#  'Honey Wheat Beer',
#  'Cream Stout',
#  'Boathouse Brown',
#  'Picadilly Porter',
#  'India Pale Lager',
#  'Red Rye Ale',
#  'Old School Pale Ale',
#  'Helles Belles',
#  'Black Forest Dunkel',
#  'Double Trouble IPA',
#  'Alpine Lager',
#  'Cat Tail Pale Ale',
#  'Bohemian Pilsener',
#  'Bumper Crop IPA',
#  'Cherry Bomb',
#  'Hoptopia',
#  'Downtown Honey Brown',
#  'Rye Saison',
#  'Pick Axe IPA',
#  'Brown Porter',
#  'Bockbier',
#  'Double Stout',
#  'Bavarian Hefeweizen',
#  'Oak Aged Porter',
#  'Northstar',
#  'Dark Horse',
#  'Imperial Red',
#  'English Pale Ale',
#  'Roggenbier',
#  'Fresh Hop 2009',
#  'Alt Beer',
#  'Java Porter',
#  'Ginger Pale Ale',
#  'Rye Of The Tiger',
#  'Buffalo Gold',
#  'Barley Wine',
#  'Holiday Spice',
#  'Premium Light',
#  'Ginger Beer',
#  'Lemon Beer',
#  'Sticke Alt',
#  'Terminally Ale',
#  'Trappist Triple',
#  'Pumpkin Head Ale',
#  'Christmas Beer',
#  'Bourbon Barrel Scotch Ale',
#  'Aces High',
#  'Deceiver',
#  'Irish Coffee Stout',
#  'Peach Hefeweizen',
#  'Echo St. IPA',
#  'Driftwood Ale',
#  'Quick Wit',
#  'Alpha Dog Imperial IPA',
#  'Nutter Brown',
#  'Divine Vamp',
#  'Razz Wheat',
#  'Kaiser',
#  'Manchester Bitter',
#  'Honey Brown',
#  'Palliser Pale Ale',
#  'Christmas Wit',
#  'Mango',
#  'Summer Saison',
#  'German Pils',
#  "Man's Best Friend",
#  'Public House Pale Ale',
#  'Mamba',
#  'Winter Wheat',
#  'Strawberry Cream Ale',
#  'Black River Red',
#  'Lincoln Lager',
#  'Vanilla Stout',
#  'Bravo',
#  '420 India Pale Ale',
#  'Dunkleweizen',
#  'Grog',
#  "Winter's Nip Holiday Porter",
#  'Czech Pils',
#  'Tiger Bite',
#  'Rauchbier',
#  'Harvest Ale',
#  'Keller Bier',
#  'Raspberry Witbier',
#  'Copperhead Red',
#  'Summer Bitter',
#  'Dorada Especial',
#  'Breakfast Stout',
#  'The Chronic',
#  'Cranberry Ale',
#  'Munich',
#  'Light Ale',
#  'Bug Lager',
#  'Raspberry Ale',
#  'Summit Pale Ale',
#  'German Alt',
#  'Northern Light',
#  'Weissbier',
#  'Unfiltered Wheat',
#  'Black And Tan',
#  'Old Town Brown',
#  'Oaktoberfest',
#  'Raspberry Pale Ale',
#  "Maggie's Irish Red",
#  'Dunkel Weizen',
#  'State Street Stout',
#  'English Mild Ale',
#  'Mardi Gras Bock',
#  'Black Mamba',
#  'Chicory Stout',
#  'Kaltenberg Pils',
#  'Single Hop Imperial IPA (Simcoe)',
#  'Half Wit',
#  'Belgian Dark',
#  'Portland Ale',
#  'Red Ale',
#  'Amber',
#  'Honey Brown Lager',
#  'Grand Cru',
#  'PM Porter',
#  'Espresso Porter',
#  'Sunrise Amber',
#  'Oud Bruin',
#  'Roggen',
#  'Barking Pumpkin',
#  'American Brown',
#  'Warrior Pale Ale',
#  'Steamer',
#  'Railyard Ale',
#  'Imperial Amber',
#  'Belgian Dubbel',
#  'Alt',
#  'Red Wheat',
#  'India Black Ale',
#  'Festival Ale',
#  "Duke's Big Ass Bock",
#  'Northern Lights Ale',
#  'Sputnik',
#  'Black Widow Imperial Stout',
#  'New York Lager',
#  'Goldihops',
#  'Foreign Extra Stout',
#  'Rye P.A.',
#  'Bohemian Blonde',
#  'Patriot Pale',
#  'Red Coat Ale',
#  'Cascade Pale Ale',
#  'Dublin Stout',
#  'Rye Bock',
#  'Dry Hopped Pale Ale',
#  'Chocolate Mint Stout',
#  'Hop Scotch Ale',
#  'Altar Boy',
#  'Harvest Rye',
#  'Speculator',
#  'Pilsener',
#  'Copperhead Pale Ale',
#  'Weizen Bier',
#  'Pale Ale',
#  'Light Lager',
#  'Barleywine 2004',
#  'Decade',
#  'Lights Out Stout',
#  'Extra Special Pale Ale',
#  'Independence Ale',
#  'Generation Ale',
#  'Buck Naked Light',
#  'Chocolate Orange Porter',
#  'Classic Porter',
#  'British Red',
#  'American Brown Ale',
#  'Drunken Monkey',
#  'Bourbon Barrel Strong Ale',
#  'Hefe',
#  'Coffee Stout',
#  'Chico Ale',
#  'Pumpkin Porter',
#  'Oktober Fest',
#  'City Pale Ale',
#  'American Amber Ale',
#  'Festivus',
#  'Chai Stout',
#  'Rye Beer',
#  'Apricot Wheat',
#  'Pelican Pale Ale',
#  'Chazz Cat Rye',
#  'South Paw',
#  'Bottoms Up',
#  'Belgian Amber',
#  'Magnum P.A.',
#  'Dubbel',
#  'Munich Dunkel',
#  'Rye Pale Ale',
#  'Dunkel Lager',
#  'Saison Nouveau',
#  'Blueberry Wheat',
#  'Blonde',
#  'Bayonet ESB',
#  'Dark Abbey',
#  'Christmas Ale',
#  'ESB',
#  'Buckwheat Ale',
#  'Cascadian Dark Ale',
#  'Wit',
#  "O'Leary's Irish Stout",
#  'Dark Wheat',
#  'Bock Lager',
#  'Vanilla Cream Ale',
#  'Anniversary Amber',
#  'Captain Fantasy',
#  'Cask Ale',
#  'Winter Solstice',
#  'Stonehenge Stout',
#  'Red Truck Lager',
#  'Fest Bier',
#  'Riverbend Red',
#  'Festbier',
#  'Bohemian Pilsner',
#  'English Barleywine',
#  'Chocolate Cherry Stout',
#  'Schwartz Bier',
#  'Copper Kettle',
#  'Pumpkin Stout',
#  'Tripel Threat',
#  'Phoenix IPA',
#  'German Hefeweizen',
#  'Weizen Bock',
#  'Lumberjack Oatmeal Stout',
#  'Black Bear Stout',
#  'Best Bitter',
#  'Dunkel Sam',
#  'Celis White',
#  'Olde Curmudgeon',
#  'Lake Effect Pale Ale',
#  'Piedmont Pilsner',
#  'Bamberger Weisse',
#  'Shaughnessy Stout',
#  'Tiber River Red',
#  ...}

# %%
beer_advocate[beer_advocate['beer_name'] == 'Apricot Ale']
# Out:
#          brewery_id                            brewery_name  review_time  \
# 66550         15218                            C.B. & Potts   1234132482
# 68521         15218                            C.B. & Potts   1315172448
# 186336         4063                  River City Brewing Co.   1164288475
# 279900         6068         Southside Speakeasy And Brewpub   1095291213
# 333555          958                Red Star Brewery & Grill   1187472498
# 527867         9104                    Front Street Brewery   1284254621
# 527868         9104                    Front Street Brewery   1282526908
# 786565          612  Flossmoor Station Restaurant & Brewery   1253462873
# 921746        12314                    Dry Dock Brewing Co.   1315862825
# 921747        12314                    Dry Dock Brewing Co.   1315528033
# 921748        12314                    Dry Dock Brewing Co.   1309999728
# 921749        12314                    Dry Dock Brewing Co.   1308616372
# 921750        12314                    Dry Dock Brewing Co.   1307550554
# 921751        12314                    Dry Dock Brewing Co.   1294073946
# 921752        12314                    Dry Dock Brewing Co.   1282503047
# 921753        12314                    Dry Dock Brewing Co.   1238426741
# 921754        12314                    Dry Dock Brewing Co.   1212116273
# 921756        12314                    Dry Dock Brewing Co.   1205090793
# 921757        12314                    Dry Dock Brewing Co.   1185654290
# 1028648         103           Middle Ages Brewing Co., Ltd.   1309538679
# 1028649         103           Middle Ages Brewing Co., Ltd.   1301700247
# 1028650         103           Middle Ages Brewing Co., Ltd.   1276224976
# 1028651         103           Middle Ages Brewing Co., Ltd.   1271808297
# 1028652         103           Middle Ages Brewing Co., Ltd.   1257553165
# 1028653         103           Middle Ages Brewing Co., Ltd.   1251781748
# 1028654         103           Middle Ages Brewing Co., Ltd.   1251656900
# 1028655         103           Middle Ages Brewing Co., Ltd.   1247263675
# 1028656         103           Middle Ages Brewing Co., Ltd.   1245971006
# 1028657         103           Middle Ages Brewing Co., Ltd.   1231807902
# 1028658         103           Middle Ages Brewing Co., Ltd.   1220504563
# ...             ...                                     ...          ...
# 1028662         103           Middle Ages Brewing Co., Ltd.   1216410410
# 1028663         103           Middle Ages Brewing Co., Ltd.   1216241178
# 1028664         103           Middle Ages Brewing Co., Ltd.   1213218793
# 1028665         103           Middle Ages Brewing Co., Ltd.   1207624331
# 1028666         103           Middle Ages Brewing Co., Ltd.   1188185551
# 1028667         103           Middle Ages Brewing Co., Ltd.   1182218511
# 1028668         103           Middle Ages Brewing Co., Ltd.   1167435567
# 1028669         103           Middle Ages Brewing Co., Ltd.   1161120221
# 1028670         103           Middle Ages Brewing Co., Ltd.   1153760472
# 1028671         103           Middle Ages Brewing Co., Ltd.   1140431766
# 1028672         103           Middle Ages Brewing Co., Ltd.   1125541881
# 1028673         103           Middle Ages Brewing Co., Ltd.   1117132812
# 1028674         103           Middle Ages Brewing Co., Ltd.   1102974502
# 1028675         103           Middle Ages Brewing Co., Ltd.   1101618121
# 1028676         103           Middle Ages Brewing Co., Ltd.   1095619501
# 1028677         103           Middle Ages Brewing Co., Ltd.   1094763811
# 1028678         103           Middle Ages Brewing Co., Ltd.   1093895285
# 1028679         103           Middle Ages Brewing Co., Ltd.   1088536181
# 1028680         103           Middle Ages Brewing Co., Ltd.   1070853458
# 1028681         103           Middle Ages Brewing Co., Ltd.   1066743008
# 1028682         103           Middle Ages Brewing Co., Ltd.   1064255663
# 1028683         103           Middle Ages Brewing Co., Ltd.   1062212039
# 1028684         103           Middle Ages Brewing Co., Ltd.   1056817055
# 1028685         103           Middle Ages Brewing Co., Ltd.   1051818669
# 1028686         103           Middle Ages Brewing Co., Ltd.   1050356111
# 1075358        5411                  Valley Brewing Company   1281839656
# 1075359        5411                  Valley Brewing Company   1265776030
# 1231001         361                    Bend Brewing Company   1317852504
# 1288558        1749      Moosejaw Pizza & Dells Brewing Co.   1231013943
# 1378093        4278         Taylor's Restaurant and Brewery   1068013144
#
#          review_overall  review_aroma  review_appearance review_profilename  \
# 66550               4.5           3.0                4.0         Haybeerman
# 68521               4.0           4.5                4.5        DenverLogan
# 186336              3.5           3.5                3.5      woodychandler
# 279900              3.5           4.0                4.0         RedDiamond
# 333555              4.0           4.0                4.0               Boto
# 527867              3.5           4.0                4.0             Duff27
# 527868              3.0           4.0                3.0          emerge077
# 786565              3.5           3.0                4.0          Thorpe429
# 921746              4.5           4.0                4.5         Haybeerman
# 921747              4.5           5.0                4.0            GilGarp
# 921748              4.5           4.5                4.0       BarrytheBear
# 921749              4.5           4.5                4.0           JCDenver
# 921750              4.5           5.0                4.0            jmkratt
# 921751              4.0           4.0                3.5     SassyBootblack
# 921752              5.0           4.5                4.0          ArrogantB
# 921753              4.0           4.0                3.5            Domingo
# 921754              4.0           4.0                4.0       filabrazilia
# 921756              5.0           4.0                4.0         drumrboy22
# 921757              4.5           3.0                3.5          Mebuzzard
# 1028648             3.5           3.5                3.5        BEERchitect
# 1028649             3.5           4.5                3.5            Knapp85
# 1028650             4.5           3.5                4.0         CaptYellow
# 1028651             3.5           3.0                3.5          beertunes
# 1028652             3.0           2.0                2.5           deapokid
# 1028653             3.0           4.0                3.0        jwarren2388
# 1028654             4.0           4.0                3.5              Durge
# 1028655             3.5           3.0                4.0         ZimZamZoom
# 1028656             4.0           4.0                3.0           jjayjaye
# 1028657             4.0           3.5                3.5            DmanGTR
# 1028658             4.0           4.0                4.0       supermanjace
# ...                 ...           ...                ...                ...
# 1028662             3.5           3.5                3.5         Reagan1984
# 1028663             3.5           4.0                4.0         number1bum
# 1028664             4.0           3.5                3.5           HopDerek
# 1028665             3.0           3.5                3.0        LumpyGuitar
# 1028666             3.5           3.5                3.5         drumrboy22
# 1028667             4.5           3.0                3.0             EPseja
# 1028668             4.0           3.5                4.0            tempest
# 1028669             3.0           2.5                3.0            kkipple
# 1028670             3.5           3.0                4.0    DarkerTheBetter
# 1028671             4.5           3.5                4.0           Chadbrew
# 1028672             3.0           4.0                4.0    blitheringidiot
# 1028673             4.0           3.5                3.0       wailingwench
# 1028674             3.0           3.0                3.0          riggser61
# 1028675             5.0           4.5                4.0              erica
# 1028676             4.0           4.0                3.5            ybnorml
# 1028677             3.5           4.0                4.0           ppoitras
# 1028678             4.0           3.5                3.5           necoadam
# 1028679             2.5           3.0                3.0               cbl2
# 1028680             3.5           3.5                3.0          Happyhour
# 1028681             3.0           2.5                4.0      ImperialScott
# 1028682             3.5           3.5                3.5      francisweizen
# 1028683             4.0           3.0                3.5          UnionMade
# 1028684             3.5           3.0                4.0             WesWes
# 1028685             2.0           3.5                3.0         cretemixer
# 1028686             4.0           3.5                3.5          Morris729
# 1075358             3.5           3.5                4.0             armock
# 1075359             4.0           4.5                3.0              vacax
# 1231001             2.5           2.0                3.0             dgilks
# 1288558             3.0           3.0                3.0            Tucquan
# 1378093             3.0           4.0                3.0       AtLagerHeads
#
#                       beer_style  review_palate  review_taste    beer_name  \
# 66550     Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 68521     Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 186336       American Blonde Ale            3.0           4.0  Apricot Ale
# 279900    Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 333555    Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 527867    Fruit / Vegetable Beer            3.0           3.0  Apricot Ale
# 527868    Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 786565    Fruit / Vegetable Beer            4.0           3.0  Apricot Ale
# 921746    Fruit / Vegetable Beer            4.5           4.5  Apricot Ale
# 921747    Fruit / Vegetable Beer            4.0           4.5  Apricot Ale
# 921748    Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 921749    Fruit / Vegetable Beer            4.0           4.5  Apricot Ale
# 921750    Fruit / Vegetable Beer            4.5           4.5  Apricot Ale
# 921751    Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 921752    Fruit / Vegetable Beer            4.0           4.5  Apricot Ale
# 921753    Fruit / Vegetable Beer            4.5           4.0  Apricot Ale
# 921754    Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 921756    Fruit / Vegetable Beer            4.0           4.5  Apricot Ale
# 921757    Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 1028648   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 1028649   Fruit / Vegetable Beer            3.5           3.0  Apricot Ale
# 1028650   Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 1028651   Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 1028652   Fruit / Vegetable Beer            2.5           3.0  Apricot Ale
# 1028653   Fruit / Vegetable Beer            2.5           3.0  Apricot Ale
# 1028654   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028655   Fruit / Vegetable Beer            3.5           3.0  Apricot Ale
# 1028656   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028657   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028658   Fruit / Vegetable Beer            4.0           4.5  Apricot Ale
# ...                          ...            ...           ...          ...
# 1028662   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028663   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 1028664   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 1028665   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 1028666   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 1028667   Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 1028668   Fruit / Vegetable Beer            4.0           3.0  Apricot Ale
# 1028669   Fruit / Vegetable Beer            3.0           2.5  Apricot Ale
# 1028670   Fruit / Vegetable Beer            4.0           4.0  Apricot Ale
# 1028671   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028672   Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 1028673   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028674   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
# 1028675   Fruit / Vegetable Beer            5.0           5.0  Apricot Ale
# 1028676   Fruit / Vegetable Beer            3.5           4.0  Apricot Ale
# 1028677   Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 1028678   Fruit / Vegetable Beer            4.0           3.5  Apricot Ale
# 1028679   Fruit / Vegetable Beer            3.0           3.0  Apricot Ale
# 1028680   Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 1028681   Fruit / Vegetable Beer            3.0           2.5  Apricot Ale
# 1028682   Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 1028683   Fruit / Vegetable Beer            4.0           3.5  Apricot Ale
# 1028684   Fruit / Vegetable Beer            4.0           3.0  Apricot Ale
# 1028685   Fruit / Vegetable Beer            3.0           2.5  Apricot Ale
# 1028686   Fruit / Vegetable Beer            3.5           3.5  Apricot Ale
# 1075358  American Pale Wheat Ale            4.0           3.5  Apricot Ale
# 1075359  American Pale Wheat Ale            3.5           3.5  Apricot Ale
# 1231001   Fruit / Vegetable Beer            3.0           2.5  Apricot Ale
# 1288558   Fruit / Vegetable Beer            3.5           3.0  Apricot Ale
# 1378093   Fruit / Vegetable Beer            3.0           3.5  Apricot Ale
#
#          beer_abv  beer_beerid
# 66550         5.0        47837
# 68521         5.0        47837
# 186336        5.1        33899
# 279900        NaN        19876
# 333555        5.4        38253
# 527867        NaN        61302
# 527868        NaN        61302
# 786565        NaN        52769
# 921746        5.1        37941
# 921747        5.1        37941
# 921748        5.1        37941
# 921749        5.1        37941
# 921750        5.1        37941
# 921751        5.1        37941
# 921752        5.1        37941
# 921753        5.1        37941
# 921754        5.1        37941
# 921756        5.1        37941
# 921757        5.1        37941
# 1028648       4.4         9460
# 1028649       4.4         9460
# 1028650       4.4         9460
# 1028651       4.4         9460
# 1028652       4.4         9460
# 1028653       4.4         9460
# 1028654       4.4         9460
# 1028655       4.4         9460
# 1028656       4.4         9460
# 1028657       4.4         9460
# 1028658       4.4         9460
# ...           ...          ...
# 1028662       4.4         9460
# 1028663       4.4         9460
# 1028664       4.4         9460
# 1028665       4.4         9460
# 1028666       4.4         9460
# 1028667       4.4         9460
# 1028668       4.4         9460
# 1028669       4.4         9460
# 1028670       4.4         9460
# 1028671       4.4         9460
# 1028672       4.4         9460
# 1028673       4.4         9460
# 1028674       4.4         9460
# 1028675       4.4         9460
# 1028676       4.4         9460
# 1028677       4.4         9460
# 1028678       4.4         9460
# 1028679       4.4         9460
# 1028680       4.4         9460
# 1028681       4.4         9460
# 1028682       4.4         9460
# 1028683       4.4         9460
# 1028684       4.4         9460
# 1028685       4.4         9460
# 1028686       4.4         9460
# 1075358       4.0        39193
# 1075359       4.0        39193
# 1231001       NaN        73815
# 1288558       NaN        47041
# 1378093       NaN        13921
#
# [62 rows x 13 columns]

# %%
len(beer_advocate['review_profilename'].unique())
# Out:
# 33388

# %%
for col in beer_advocate.columns:
    print(col, len(beer_advocate[col].unique()))
# Out:
# brewery_id 5840
# brewery_name 5743
# review_time 1577960
# review_overall 10
# review_aroma 9
# review_appearance 10
# review_profilename 33388
# beer_style 104
# review_palate 9
# review_taste 9
# beer_name 56857
# beer_abv 531
# beer_beerid 66055

# %%
beer_advocate['beer_abv'].describe()
# Out:
# count    1.518829e+06
# mean     7.042387e+00
# std      2.322526e+00
# min      1.000000e-02
# 25%      5.200000e+00
# 50%      6.500000e+00
# 75%      8.500000e+00
# max      5.770000e+01
# Name: beer_abv, dtype: float64

# %%
beer_advocate.sort_values('beer_abv', ascending=False).head()
# Out:
#         brewery_id  brewery_name  review_time  review_overall  review_aroma  \
# 12919         6513  Schorschbräu   1316780901             4.0           4.0
# 12939         6513  Schorschbräu   1309974178             4.0           4.0
# 12940         6513  Schorschbräu   1274469798             3.5           4.0
# 746385       16315       BrewDog   1285808609             3.5           4.0
# 746387       16315       BrewDog   1285274059             3.0           3.0
#
#         review_appearance review_profilename                      beer_style  \
# 12919                 4.0        kappldav123                         Eisbock
# 12939                 3.5           Sunnanek                         Eisbock
# 12940                 4.0        kappldav123                         Eisbock
# 746385                4.0              bobsy  American Double / Imperial IPA
# 746387                3.0             cratez  American Double / Imperial IPA
#
#         review_palate  review_taste                      beer_name  beer_abv  \
# 12919             4.0           3.5  Schorschbräu Schorschbock 57%      57.7
# 12939             4.0           4.0  Schorschbräu Schorschbock 43%      43.0
# 12940             4.0           4.5  Schorschbräu Schorschbock 43%      43.0
# 746385            4.0           4.0             Sink The Bismarck!      41.0
# 746387            3.0           3.5             Sink The Bismarck!      41.0
#
#         beer_beerid
# 12919         73368
# 12939         57856
# 12940         57856
# 746385        57015
# 746387        57015

# %%
beer_advocate[beer_advocate['beer_abv'] > 15].shape
# Out:
# (10464, 13)

# %%
beer_advocate.groupby('beer_beerid').count()['review_overall'][beer_advocate.groupby('beer_beerid').count()['review_overall'] > 10].shape
# Out:
# (13389,)

# %%
beer_advocate.groupby('beer_name').count()['review_overall'][beer_advocate.groupby('beer_name').count()['review_overall'] > 10].shape
# Out:
# (13067,)

# %%
duplicate_names = []
for name in beer_advocate['beer_name'].unique():
    if len(beer_advocate[beer_advocate['beer_name'] == name]['beer_beerid'].unique()) > 1:
        duplicate

# %%
import requests

# %%
url = 'https://www.brewtoad.com/recipes?page=1&sort=rank'

res = requests.get(url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
base_url = 'http://www.brewtoad.com'

# %%
recipe_links = soup.find_all('a', attrs={'class': 'recipe-link'})

# %%
recipes = []
for i in recipe_links:
    # Get new URL
    new_url = base_url + i.attrs['href']
    
    # Use new URL to generate new request
    new_res = requests.get(new_url)
    
    # Create new beautiful soup parser
    new_soup = BeautifulSoup(new_res.content, 'lxml')
    
    #instantiate recipe dictionary
    recipe = {}
    
    # Find Name and Style
    recipe['name'] = new_soup.find('h1').text.strip()
    recipe['style'] = new_soup.find('div', attrs={'class': 'header-content'}).find('a').text.strip()
    
    # Find base stats and append to dictionary
    base_stats = new_soup.find_all('div', attrs={'class': 'value'})
    recipe['OG'] = base_stats[0].text
    recipe['FG'] = base_stats[1].text
    recipe['IBU'] = base_stats[2].text
    recipe['SRM'] = base_stats[3].text
    recipe['ABV'] = base_stats[4].text
    
    # Find fermentables and append to dictionary
    grains = new_soup.find('table', attrs={'id': 'fermentables'}).find('tbody').find_all('tr')
    fermentables = []
    for g in grains:
        row = g.find_all('td')
        fermentable = {}
        fermentable['amount'] = row[0].text.strip()
        fermentable['name'] = row[1].text.strip()
        fermentable['maltster'] = row[2].text.strip()
        fermentable['use'] = row[3].text.strip()
        fermentable['PPG'] = row[4].text.strip()
        fermentable['color'] = row[5].text.replace('\n', '')
        fermentables.append(fermentable)
    recipe['fermentables'] = fermentables
    
    # Find hops and append to dictionary
    hop_table = new_soup.find('table', attrs={'id': 'hops'}).find('tbody').find_all('tr')
    hops = []
    for h in hop_table:
        row = h.find_all('td')
        hop = {}
        hop['amount'] = row[0].text.replace('\n', '')
        hop['name'] = row[1].text.replace('\n', '')
        hop['time'] = row[2].text.replace('\n', '')
        hop['use'] = row[3].text.replace('\n', '')
        hop['form'] = row[4].text.replace('\n', '')
        hop['alpha'] = row[5].text.replace('\n', '')
        hops.append(hop)
    recipe['hops'] = hops
    
    # Find yeast
# Out:
# {'OG': '1.053', 'FG': '1.012', 'IBU': '18', 'SRM': '4', 'ABV': '5.4%'}
# {'OG': '1.068', 'FG': '1.018', 'IBU': '68', 'SRM': '6', 'ABV': '6.6%'}
# {'OG': '1.070', 'FG': '1.018', 'IBU': '53', 'SRM': '8', 'ABV': '6.9%'}
# {'OG': '1.059', 'FG': '1.016', 'IBU': '31', 'SRM': '24', 'ABV': '5.6%'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-bd82b866c20f> in <module>()
#       2 for i in recipe_links:
#       3     new_url = base_url + i.attrs['href']
# ----> 4     new_res = requests.get(new_url)
#       5     new_soup = BeautifulSoup(new_res.content, 'lxml')
#       6     base_stats = new_soup.find_all('div', attrs={'class': 'value'})
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in <listcomp>(.0)
#     638
#     639         # Resolve redirects if allowed.
# --> 640         history = [resp for resp in gen] if allow_redirects else []
#     641
#     642         # Shuffle things around if there's history.
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     216                     proxies=proxies,
#     217                     allow_redirects=False,
# --> 218                     **adapter_kwargs
#     219                 )
#     220
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
test_url = 'https://www.brewtoad.com/recipes/firework-cream-ale'
test_res = requests.get(test_url)
bs = BeautifulSoup(test_res.content, 'lxml')
# grains = bs.find('table', attrs={'id': 'fermentables'}).find('tbody').find_all('tr')
# fermentables = []
# for g in grains:
#     row = g.find_all('td')
#     fermentable = {}
#     fermentable['amount'] = row[0].text.strip()
#     fermentable['name'] = row[1].text.strip()
#     fermentable['maltster'] = row[2].text.strip()
#     fermentable['use'] = row[3].text.strip()
#     fermentable['PPG'] = row[4].text.strip()
#     fermentable['color'] = row[5].text.replace('\n', '')
#     fermentables.append(fermentable)
# fermentables

# hop_table = bs.find('table', attrs={'id': 'hops'}).find('tbody').find_all('tr')
# hops = []
# for h in hop_table:
#     row = h.find_all('td')
#     hop = {}
#     hop['amount'] = row[0].text.replace('\n', '')
#     hop['name'] = row[1].text.replace('\n', '')
#     hop['time'] = row[2].text.replace('\n', '')
#     hop['use'] = row[3].text.replace('\n', '')
#     hop['form'] = row[4].text.replace('\n', '')
#     hop['alpha'] = row[5].text.replace('\n', '')
#     hops.append(hop)
# hops

# yeast_table = bs.find('table', attrs={'id': 'yeasts'}).find('tbody').find_all('tr')
# yeasts = []
# for y in yeast_table:
#     row = y.find_all('td')
#     yeast = {}
#     yeast['name'] = row[0].text.strip()
#     yeast['lab'] = row[1].text.strip().replace('\n', ' ')
#     yeast['attenuation'] = row[2].text.strip()
#     yeasts.append(yeast)
# yeasts

final_stats = bs.find('ul', attrs={'class': 'stat-group-thirds'}).find_all('li')
recipe['volume'] = final_stats[0].text.strip().split('\n')[1]
recipe['vol_units'] = final_stats[0].text.strip().split('\n')[1]
recipe['boil_time'] = final_stats[1].text.replace('Boil Time', '').strip()
# Out:
# '90 min'
